# %%
import requests
from bs4 import BeautifulSoup
# !dir
# Out:
#  Volume in drive C is Acer
#  Volume Serial Number is 5A98-2176
#
#  Directory of C:\Users\route\Documents\GitCS499
#
# 04/28/2018  11:29 PM    <DIR>          .
# 04/28/2018  11:29 PM    <DIR>          ..
# 04/28/2018  11:29 PM    <DIR>          .ipynb_checkpoints
# 04/17/2018  05:02 PM                47 README.md
# 04/17/2018  05:31 PM           419,463 SemesterProject.ipynb
#                2 File(s)        419,510 bytes
#                3 Dir(s)   2,211,454,976 bytes free

# %%
url = 'http://www.showmeboone.com/sheriff/JailResidents/JailResidents.asp'
response = requests.get(url)
html = response.content
print(html)
soup = BeautifulSoup(html)
print(soup.prettify())
# Out:
# b'<!DOCTYPE html>\n<html>\n    <head>        <title>Current Detainees of Boone County Jail</title>\n        <meta content="IE=edge" http-equiv="X-UA-Compatible" />\n        <meta content="width=device-width, initial-scale=1.0" name="viewport" />\n<!--  -->\n<!-- MultipleRecordApp: CURRENT DETAINEES. Created: Thu Apr 06 13:51:13 CDT 2017 by ITBRANDO. INQHTM-MUL 20120709 -->\n        <link href="/mrcjava/mrcclasses/SH01_MP/favicon.ico" rel="shortcut icon" />\n        <link href="/mrcjava/mrcclasses/mrc_servlet_ajax.css" rel="stylesheet" type="text/css" />\n        <link href="/mrcjava/mrcclasses/SH01_MP/mrc_default.css?v=0.74" mrcfile="150" rel="stylesheet" type="text/css" />\n        <link href="/mrcjava/mrcclasses/jquery.custom.css" rel="stylesheet" type="text/css" />\n<!--[if !IE]>\n<link href="/mrcjava/mrcclasses/mrc-responsive.css" rel="stylesheet" />\n<![endif]-->\n<!--[if IE 7]>\n<link href="/mrcjava/mrcclasses/font/css/font-awesome-ie7.css" rel="stylesheet" />\n<![endif]-->\n        <style type="text/css">#sort_table_head a {pointer-events: none;}\n          #sort_table_head i {display: none;}\n      #sort_table_head [data-col="LASTNP"] a, \n      #sort_table_head [data-col="FIRSTP"] a {\n            pointer-events: initial;}\n      #sort_table_head [data-col="LASTNP"] i, \n      #sort_table_head [data-col="FIRSTP"] i {\n            display: initial;}\n          .viewCount {text-align: center;}\n          .filterOptions.mobileOnly {display: none;}\n          /*@media screen and (min-width: 761px) {\n            body > div.ui-dialog {\n              top: 50% !important;\n              transform: translateY(-50%);\n            }\n          }*/</style>\n<script type="text/javascript" src="/mrcjava/mrcclasses/mpowerapps.js"></script>\n<script type="text/javascript" src="/mrcjava/mrcclasses/SH01_MP/js/mobileSortAndFilter.js" mrcfile="mobileSortAndFilter.js"></script>\n<script type="text/javascript" src="/mrcjava/mrcclasses/SH01_MP/js/websiteNotification.js" mrcfile="websiteNotification.js"></script>\n<script type="text/javascript">\n      var s1 = new Image().src = \'/mrcjava/image/ascg.gif\',\n          s0 = new Image().src = \'/mrcjava/image/descg.gif\';\n    </script>\n    </head>\n\n    <body>\n<!-- Begin mrc Header -->\n        <div class="page-wrap">\n<!---->\n<!-- Begin mrc Default Desktop Header -->\n<!-- Begin JavaScript Required Message -->\n<noscript>\n\t<div class="warning noJS">\n\t\tThe Boone County website <strong>requires</strong> JavaScript to function correctly. Please enable JavaScript in your browser.\n\t</div>\n</noscript>\n<!-- End JavaScript Required Message -->\n<!-- Begin Image Bar -->\n<div class="pageHeader DepartmentHeader container">\n  <div class="DepartmentHeaderGraphic">\n    <img src="/mrcjava/mrcclasses/SH01_MP/BCSD-title2.jpg" alt="Boone County Sheriff\'s Badge" />\n  </div>\n  <div class="DepartmentHeaderInfo">\n    <div class="DepartmentHeaderTitle">\n      Boone County Sheriff\'s Department\n    </div>\n    <div class="container">\n      <div class="DepartmentHeaderAddress">\n        Boone County Sheriff\'s Department<br />\n        2121 County Dr.<br />\n        Columbia, MO 65202\n      </div>\n      <div class="DepartmentHeaderNumbers">\n        Office (573) 875-1111<br />\n        Fax (573) 874-8953\n      </div>\n    </div>\n  </div>\n</div>  \n<!-- End Image Bar -->\n<!-- Begin Link Bar -->\n<div id="headerMenu" class="container noPrint">\n  <ul>\n    <li>\n      <a href="http://www.boonecountymo.org/sheriff">\n        Home\n      </a>\n    </li>\n    <li class="mainMenu">\n      <a href="/mrcjava/servlet/SH01_MP.I00040s">\n        Menu\n      </a>\n    </li>\n    <li>\n      <a class="" href="/mrcjava/servlet/SH01_MP.I00030s" target="_new">\n        Help\n      </a>\n    </li>\n    <!--<li class="options">\n      <a href="#"  onclick="viewOptions();">\n        Options\n      </a>\n    </li>-->\n  </ul>\n</div>\n<!-- End Link Bar -->\n<!-- End mrc Default Desktop Header -->\n<!-- Be ...
# c:\users\route\appdata\local\programs\python\python36-32\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html5lib"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file c:\users\route\appdata\local\programs\python\python36-32\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "html5lib")
#
#   markup_type=markup_type))
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Current Detainees of Boone County Jail
#   </title>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <!--  -->
#   <!-- MultipleRecordApp: CURRENT DETAINEES. Created: Thu Apr 06 13:51:13 CDT 2017 by ITBRANDO. INQHTM-MUL 20120709 -->
#   <link href="/mrcjava/mrcclasses/SH01_MP/favicon.ico" rel="shortcut icon"/>
#   <link href="/mrcjava/mrcclasses/mrc_servlet_ajax.css" rel="stylesheet" type="text/css"/>
#   <link href="/mrcjava/mrcclasses/SH01_MP/mrc_default.css?v=0.74" mrcfile="150" rel="stylesheet" type="text/css"/>
#   <link href="/mrcjava/mrcclasses/jquery.custom.css" rel="stylesheet" type="text/css"/>
#   <!--[if !IE]>
# <link href="/mrcjava/mrcclasses/mrc-responsive.css" rel="stylesheet" />
# <![endif]-->
#   <!--[if IE 7]>
# <link href="/mrcjava/mrcclasses/font/css/font-awesome-ie7.css" rel="stylesheet" />
# <![endif]-->
#   <style type="text/css">
#    #sort_table_head a {pointer-events: none;}
#           #sort_table_head i {display: none;}
#       #sort_table_head [data-col="LASTNP"] a,
#       #sort_table_head [data-col="FIRSTP"] a {
#             pointer-events: initial;}
#       #sort_table_head [data-col="LASTNP"] i,
#       #sort_table_head [data-col="FIRSTP"] i {
#             display: initial;}
#           .viewCount {text-align: center;}
#           .filterOptions.mobileOnly {display: none;}
#           /*@media screen and (min-width: 761px) {
#             body > div.ui-dialog {
#               top: 50% !important;
#               transform: translateY(-50%);
#             }
#           }*/
#   </style>
#   <script src="/mrcjava/mrcclasses/mpowerapps.js" type="text/javascript">
#   </script>
#   <script mrcfile="mobileSortAndFilter.js" src="/mrcjava/mrcclasses/SH01_MP/js/mobileSortAndFilter.js" type="text/javascript">
#   </script>
#   <script mrcfile="websiteNotification.js" src="/mrcjava/mrcclasses/SH01_MP/js/websiteNotification.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    var s1 = new Image().src = '/mrcjava/image/ascg.gif',
#           s0 = new Image().src = '/mrcjava/image/descg.gif';
#   </script>
#  </head>
#  <body>
#   <!-- Begin mrc Header -->
#   <div class="page-wrap">
#    <!---->
#    <!-- Begin mrc Default Desktop Header -->
#    <!-- Begin JavaScript Required Message -->
#    <noscript>
#     <div class="warning noJS">
#      The Boone County website
#      <strong>
#       requires
#      </strong>
#      JavaScript to function correctly. Please enable JavaScript in your browser.
#     </div>
#    </noscript>
#    <!-- End JavaScript Required Message -->
#    <!-- Begin Image Bar -->
#    <div class="pageHeader DepartmentHeader container">
#     <div class="DepartmentHeaderGraphic">
#      <img alt="Boone County Sheriff's Badge" src="/mrcjava/mrcclasses/SH01_MP/BCSD-title2.jpg"/>
#     </div>
#     <div class="DepartmentHeaderInfo">
#      <div class="DepartmentHeaderTitle">
#       Boone County Sheriff's Department
#      </div>
#      <div class="container">
#       <div class="DepartmentHeaderAddress">
#        Boone County Sheriff's Department
#        <br/>
#        2121 County Dr.
#        <br/>
#        Columbia, MO 65202
#       </div>
#       <div class="DepartmentHeaderNumbers">
#        Office (573) 875-1111
#        <br/>
#        Fax (573) 874-8953
#       </div>
#      </div>
#     </div>
#    </div>
#    <!-- End Image Bar -->
#    <!-- Begin Link Bar -->
#    <div class="container noPrint" id="headerMenu">
#     <ul>
#      <li>
#       <a href="http://www.boonecountymo.org/sheriff">
#        Home
#       </a>
#      </li>
#      <li class="mainMenu">
#       <a href="/mrcjava/servlet/SH01_MP.I00040s">
#        Menu
#       </a>
#      </li>
#      <li>
#       <a class="" href="/mrcjava/servlet/SH01_MP.I00030s" target="_new">
#        Help
#       </a>
#      </li>
#      <!--<li class="options">
#       <a href="#"  onclick="viewOptions();">
#         Options
#       </a>
#     </li>-->
#     </ul>
#    </div>
#    <!-- End Link Bar -->
#    <!-- End mrc Default Desktop Header -->
#    <!-- Begin BC Custom Mobile Header-->
#    <div class="fixedHeader">
#     <div class="fixedHeaderButton bcSealButton">
#      <a class="transparent" href="http://www.boonecountymo.org/Sheriff/">
#       <img alt="Boone County Sheriff's Badge" class="bcSeal shBadge" src="/mrcjava/mrcclasses/SH01_MP/BCSD-title2.jpg"/>
#      </a>
#     </div>
#     <div class="fixedHeaderButton menuButton">
#      <!--Link to custom menu page-->
#      <a class="transparent" href="/mrcjava/servlet/SH01_MP.I00040s">
#       Menu
#      </a>
#     </div>
#     <!--<div class="options fixedHeaderButton optionsButton">
#   <a class="transparent" href="#" id="options" onclick="viewOptions();">
#     <i class="fa fa-2x fa-gear optionsIcon">&nbsp;</i>
#   </a>
#   </div>-->
#     <div class="fixedHeaderButton helpButton">
#      <!--Link to help page-->
#      <a class="transparent" href="/mrcjava/servlet/SH01_MP.I00030s">
#       Help
#      </a>
#     </div>
#     <div class="fixedHeaderButton optionsButton hiddenButton">
#     </div>
#     <div class="headerTitle">
#      <!--Link to department home page-->
#      <a class="transparent" href="http://www.boonecountymo.org/Sheriff/">
#       Boone County Sheriff's Department
#      </a>
#     </div>
#    </div>
#    <!-- End BC Custom Mobile Header-->
#    <script type="text/javascript">
#     if (window.location.hostname == "s10ccd5c.boonecountymo.org") {
#    jQuery('a[href="/mrcjava/servlet/BC00_MP.mrcMenu"]').attr(
#      'href',
#      '/mrcjava/servlet/MRCTEST.mrcMenu'
#    );
#  }
#    </script>
#    <!---->
#    <!-- End mrc Header -->
#    <!-- Begin Title Bar -->
#    <div class="title">
#     Current Detainees of Boone County Jail
#    </div>
#    <!-- End Title Bar -->
#    <!---->
#    <div id="applicationOptions" style="padding: 10px; DISPLAY: none; FONT: 8pt verdana;">
#     <table cellpadding="0" cellspacing="0" class="collapse BCSDTable shadow">
#      <tbody>
#       <tr class="even">
#        <!-- -->
#        <td class="two" style="border-bottom:1px solid #000" valign="top">
#         <table border="0" cellpadding="1" cellspacing="1" class="BCSDTable" width="350">
#          <tbody>
#           <tr>
#            <th>
#             Saved Searches
#            </th>
#           </tr>
#           <tr>
#            <td align="left" style="PADDING-LEFT: 10px; PADDING-RIGHT: 10px">
#             <div id="search_input">
#              <br/>
#              <font size="2">
#               <strong>
#                Name Current Search:
#               </strong>
#               <br/>
#              </font>
#              <input id="dialogViewName" name="dialogViewName" size="35"/>
#              <img alt="" height="19" onclick="saveView();" src="/mrcjava/image/view_save.png" style="CURSOR: pointer" width="20"/>
#              <br/>
#             </div>
#             <br/>
#             <font size="2">
#              <strong>
#               Execute Saved Search:
#              </strong>
#             </font>
#             <br/>
#             <table border="0" cellpadding="1" cellspacing="1" mrc_app="SH01_MP.I00290s">
#              <tbody>
#              </tbody>
#             </table>
#             <br/>
#            </td>
#           </tr>
#          </tbody>
#         </table>
#        </td>
#        <!-- -->
#        <td class="two" style="border-bottom:1px solid #000" valign="top">
#         <table border="0" cellpadding="1" cellspacing="1" class="BCSDTable" width="200">
#          <tbody>
#           <tr>
#            <th>
#             Browser Mode
#            </th>
#           </tr>
#           <tr>
#            <td align="left" style="PADDING-LEFT: 10px; PADDING-RIGHT: 10px">
#             <br/>
#             <font size="2">
#              <strong>
#               Select Browsing Mode:
#              </strong>
#             </font>
#             <br/>
#             <br/>
#             <table border="0" cellpadding="1" cellspacing="1" id="device_select_table">
#              <tbody>
#               <tr>
#                <td>
#                 <img src="/mrcjava/image/check.png"/>
#                </td>
#                <td>
#                 <font size="2">
#                  <a class="standard" href="#" onclick="switchDevice('pc')">
#                   PC
#                  </a>
#                 </font>
#                </td>
#               </tr>
#               <tr>
#                <td>
#                </td>
#                <td>
#                 <font size="2">
#                  <a class="standard" href="#" onclick="switchDevice('mob')">
#                   Mobile
#                  </a>
#                 </font>
#                </td>
#               </tr>
#              </tbody>
#             </table>
#            </td>
#           </tr>
#          </tbody>
#         </table>
#        </td>
#       </tr>
#      </tbody>
#     </table>
#    </div>
#    <!---->
#    <div class="ajax_content table-wrapper box-shadow" id="mrcMainContent">
#     <form action="SH01_MP.I00290s" autocomplete="off" data-app_type="I" id="FORM_I00290" method="post" name="FORM_I00290">
#      <!-- Begin Run Time Message -->
#      <div class="errortext1">
#      </div>
#      <!-- End Run Time Message -->
#      <div class="searchWrapper">
#       <div class="search card">
#        <div class="card-title">
#         Search By Name
#        </div>
#        <div class="card-block">
#         <div>
#          <label>
#           Last Name:
#          </label>
#          <select class="mrcselect relation" id="F_C_LI_LASTNP" name="rls_LASTNP">
#           <option title="Equal" value="EQ">
#            EQ
#           </option>
#           <option title="Not equal" value="NE">
#            NE
#           </option>
#           <option title="Greater than or equal" value="GE">
#            GE
#           </option>
#           <option title="Greater than" value="GT">
#            GT
#           </option>
#           <option title="Less than or equal" value="LE">
#            LE
#           </option>
#           <option title="Less than" value="LT">
#            LT
#           </option>
#           <option title="In the list" value="LS">
#            LS
#           </option>
#           <option title="Not in the list" value="NS">
#            NS
#           </option>
#           <option title="In the range" value="RG">
#            RG
#           </option>
#           <option title="Not in the range" value="NR">
#            NR
#           </option>
#           <option title="Contains" value="CT">
#            CT
#           </option>
#           <option title="Does not Contain" value="NC">
#            NC
#           </option>
#           <option title="Contains all" value="CA">
#            CA
#           </option>
#           <option selected="selected" title="Contains any" value="CO">
#            CO
#           </option>
#           <option title="Starts with" value="SW">
#            SW
#           </option>
#           <option title="Does not Start with" value="NW">
#            NW
#           </option>
#          </select>
#          <input class="mrcinput" id="val_LASTNP" name="val_LASTNP" size="32" title="val_LASTNP" type="text" value=""/>
#         </div>
#         <div>
#          <label>
#           First Name:
#          </label>
#          <select class="mrcselect relation" id="F_C_LI_FIRSTP" name="rls_FIRSTP">
#           <option title="Equal" value="EQ">
#            EQ
#           </option>
#           <option title="Not equal" value="NE">
#            NE
#           </option>
#           <option title="Greater than or equal" value="GE">
#            GE
#           </option>
#           <option title="Greater than" value="GT">
#            GT
#           </option>
#           <option title="Less than or equal" value="LE">
#            LE
#           </option>
#           <option title="Less than" value="LT">
#            LT
#           </option>
#           <option title="In the list" value="LS">
#            LS
#           </option>
#           <option title="Not in the list" value="NS">
#            NS
#           </option>
#           <option title="In the range" value="RG">
#            RG
#           </option>
#           <option title="Not in the range" value="NR">
#            NR
#           </option>
#           <option title="Contains" value="CT">
#            CT
#           </option>
#           <option title="Does not Contain" value="NC">
#            NC
#           </option>
#           <option title="Contains all" value="CA">
#            CA
#           </option>
#           <option selected="selected" title="Contains any" value="CO">
#            CO
#           </option>
#           <option title="Starts with" value="SW">
#            SW
#           </option>
#           <option title="Does not Start with" value="NW">
#            NW
#           </option>
#          </select>
#          <input class="mrcinput" id="val_FIRSTP" name="val_FIRSTP" size="32" title="val_FIRSTP" type="text" value=""/>
#         </div>
#         <div>
#          <button class="btn btn-primary" name="btn_search" type="submit">
#           <i class="fa fa-large fa-search">
#           </i>
#           Search
#          </button>
#          <button class="btn btn-default" name="btn_reset" type="reset">
#           <i class="fa fa-large fa-repeat">
#           </i>
#           Reset
#          </button>
#          <a class="btn btn-default" href="SH01_MP.R00250s?run=2">
#           <i class="fa fa-large fa-file-excel-o">
#           </i>
#           Export Detainees &amp; Charges to Excel
#          </a>
#         </div>
#        </div>
#        <div class="card-block">
#         <strong>
#          Run Date: 04/17/18
#         </strong>
#        </div>
#       </div>
#      </div>
#      <!-- Begin Data Table -->
#      <script>
#       jQuery(document).ready(function(){         var greynames=new Array("s1LASTNP","s1FIRSTP","s1MIDDLP","s1PERKEP"); setSortImage2(greynames,'FORM_I00290'); });
#      </script>
#      <table cellspacing="0" class="collapse data-table shadow responsive">
#       <thead>
#        <tr class="tr-paging">
#         <th class="th_left paging_row" colspan="93">
#          <!---->
#          <!--<button class="btn btn-primary" name="btn_search" type="submit"><i class="fa fa-large fa-filter">&nbsp;</i> Filter</button>-->
#          241 Total Items  |  Page Size
#          <input class="mrcinput" name="max_rows" size="3" title="max_rowsp" type="text" value="50"/>
#          <!--   -->
#          <!--
# <img alt class="to-excel-img" src="/mrcjava/image/format_excel.png" title="Microsoft Excel format" /> &nbsp; -->
#          <!-- -->
#          <div class="pagination pagination-right fixed-pagination">
#           <ul>
#            <li>
#             <a class="page-button" data-pagetype="btn_top" href="javascript:void(0)">
#              <i class="fa fa-angle-double-left fa-large">
#              </i>
#             </a>
#            </li>
#            <li>
#             <a class="page-button" data-pagetype="btn_prev" href="javascript:void(0)">
#              <i class="fa fa-angle-left fa-large">
#              </i>
#             </a>
#            </li>
#            <li class="disabled">
#             <a href="#">
#              Page 1 of 5
#             </a>
#            </li>
#            <li>
#             <a class="page-button" data-pagetype="btn_next" href="javascript:void(0)">
#              <i class="fa fa-angle-right fa-large">
#              </i>
#             </a>
#            </li>
#            <li>
#             <a class="page-button" data-pagetype="btn_btmm" href="javascript:void(0)">
#              <i class="fa fa-angle-double-right fa-large">
#              </i>
#             </a>
#            </li>
#           </ul>
#          </div>
#         </th>
#        </tr>
#        <!--BEGIN_SORT_TABLE_HEADER-->
#        <tr class="table-header" id="sort_table_head">
#         <th data-col="LASTNP">
#          <a class="sort-col" data-field="LASTNP" href="javascript:void(0)">
#           Last Name
#           <i class="fa fa-sort">
#           </i>
#          </a>
#         </th>
#         <th data-col="FIRSTP">
#          <a class="sort-col" data-field="FIRSTP" href="javascript:void(0)">
#           First Name
#           <i class="fa fa-sort">
#           </i>
#          </a>
#         </th>
#         <th class="hideOnMobile" data-col="MIDDLP">
#          <a class="sort-col" data-field="MIDDLP" href="javascript:void(0)">
#           Middle Name
#           <i class="fa fa-sort">
#           </i>
#          </a>
#         </th>
#         <th class="hideOnMobile" data-col="SEXCOP">
#          <a class="sort-col" data-field="SEXCOP" href="javascript:void(0)">
#           Sex
#           <i class="fa fa-sort">
#           </i>
#          </a>
#         </th>
#         <th class="hideOnMobile" data-col="RACECP">
#          <a class="sort-col" data-field="RACECP" href="javascript:void(0)">
#           Race
#           <i class="fa fa-sort">
#           </i>
#          </a>
#         </th>
#         <th class="hideOnMobile" data-col="AGEBEP">
#          <a class="sort-col" data-field="AGEBEP" href="javascript:void(0)">
#           Age
#           <i class="fa fa-sort">
#           </i>
#          </a>
#         </th>
#         <th class="hideOnMobile" data-col="CITYMP">
#          <a class="sort-col" data-field="CITYMP" href="javascript:void(0)">
#           City
#           <i class="fa fa-sort">
#           </i>
#          </a>
#         </th>
#         <th class="hideOnMobile" data-col="STATEP">
#          <a class="sort-col" data-field="STATEP" href="javascript:void(0)">
#           State
#           <i class="fa fa-sort">
#           </i>
#          </a>
#         </th>
#         <th class="hideOnMobile">
#         </th>
#        </tr>
#        <!--END_SORT_TABLE_HEADER-->
#        <!--BEGIN_ADVANCED_SEARCH-->
#        <!---->
#        <tr id="search_table_head" style="display: none;">
#         <th align="center">
#          <a class="nav" href="/mrcjava/mrcclasses/filter_relationship_help.html" linkedtype="" target="_blank" title="Filter Relationship Help">
#           ?
#          </a>
#          <select class="mrcselect relation" id="F_C_LI_LASTNP" name="rls_LASTNP">
#           <option title="Equal" value="EQ">
#            EQ
#           </option>
#           <option title="Not equal" value="NE">
#            NE
#           </option>
#           <option title="Greater than or equal" value="GE">
#            GE
#           </option>
#           <option title="Greater than" value="GT">
#            GT
#           </option>
#           <option title="Less than or equal" value="LE">
#            LE
#           </option>
#           <option title="Less than" value="LT">
#            LT
#           </option>
#           <option title="In the list" value="LS">
#            LS
#           </option>
#           <option title="Not in the list" value="NS">
#            NS
#           </option>
#           <option title="In the range" value="RG">
#            RG
#           </option>
#           <option title="Not in the range" value="NR">
#            NR
#           </option>
#           <option title="Contains" value="CT">
#            CT
#           </option>
#           <option title="Does not Contain" value="NC">
#            NC
#           </option>
#           <option title="Contains all" value="CA">
#            CA
#           </option>
#           <option title="Contains any" value="CO">
#            CO
#           </option>
#           <option title="Starts with" value="SW">
#            SW
#           </option>
#           <option title="Does not Start with" value="NW">
#            NW
#           </option>
#          </select>
#          <input class="mrcinput" id="val_LASTNP" name="val_LASTNP" size="6" title="val_LASTNP" type="text" value=""/>
#         </th>
#         <th align="center">
#          <select class="mrcselect relation" id="F_C_LI_FIRSTP" name="rls_FIRSTP">
#           <option title="Equal" value="EQ">
#            EQ
#           </option>
#           <option title="Not equal" value="NE">
#            NE
#           </option>
#           <option title="Greater than or equal" value="GE">
#            GE
#           </option>
#           <option title="Greater than" value="GT">
#            GT
#           </option>
#           <option title="Less than or equal" value="LE">
#            LE
#           </option>
#           <option title="Less than" value="LT">
#            LT
#           </option>
#           <option title="In the list" value="LS">
#            LS
#           </option>
#           <option title="Not in the list" value="NS">
#            NS
#           </option>
#           <option title="In the range" value="RG">
#            RG
#           </option>
#           <option title="Not in the range" value="NR">
#            NR
#           </option>
#           <option title="Contains" value="CT">
#            CT
#           </option>
#           <option title="Does not Contain" value="NC">
#            NC
#           </option>
#           <option title="Contains all" value="CA">
#            CA
#           </option>
#           <option title="Contains any" value="CO">
#            CO
#           </option>
#           <option title="Starts with" value="SW">
#            SW
#           </option>
#           <option title="Does not Start with" value="NW">
#            NW
#           </option>
#          </select>
#          <input class="mrcinput" id="val_FIRSTP" name="val_FIRSTP" size="6" title="val_FIRSTP" type="text" value=""/>
#         </th>
#         <th align="center">
#          <select class="mrcselect relation" id="F_C_LI_MIDDLP" name="rls_MIDDLP">
#           <option title="Equal" value="EQ">
#            EQ
#           </option>
#           <option title="Not equal" value="NE">
#            NE
#           </option>
#           <option title="Greater than or equal" value="GE">
#            GE
#           </option>
#           <option title="Greater than" value="GT">
#            GT
#           </option>
#           <option title="Less than or equal" value="LE">
#            LE
#           </option>
#           <option title="Less than" value="LT">
#            LT
#           </option>
#           <option title="In the list" value="LS">
#            LS
#           </option>
#           <option title="Not in the list" value="NS">
#            NS
#           </option>
#           <option title="In the range" value="RG">
#            RG
#           </option>
#           <option title="Not in the range" value="NR">
#            NR
#           </option>
#           <option title="Contains" value="CT">
#            CT
#           </option>
#           <option title="Does not Contain" value="NC">
#            NC
#           </option>
#           <option title="Contains all" value="CA">
#            CA
#           </option>
#           <option title="Contains any" value="CO">
#            CO
#           </option>
#           <option title="Starts with" value="SW">
#            SW
#           </option>
#           <option title="Does not Start with" value="NW">
#            NW
#           </option>
#          </select>
#          <input class="mrcinput" id="val_MIDDLP" name="val_MIDDLP" size="6" title="val_MIDDLP" type="text" value=""/>
#         </th>
#         <th align="center">
#          <select class="mrcselect relation" id="F_C_LI_SEXCOP" name="rls_SEXCOP">
#           <option title="Equal" value="EQ">
#            EQ
#           </option>
#           <option title="Not equal" value="NE">
#            NE
#           </option>
#           <option title="Greater than or equal" value="GE">
#            GE
#           </option>
#           <option title="Greater than" value="GT">
#            GT
#           </option>
#           <option title="Less than or equal" value="LE">
#            LE
#           </option>
#           <option title="Less than" value="LT">
#            LT
#           </option>
#           <option title="In the list" value="LS">
#            LS
#           </option>
#           <option title="Not in the list" value="NS">
#            NS
#           </option>
#           <option title="In the range" value="RG">
#            RG
#           </option>
#           <option title="Not in the range" value="NR">
#            NR
#           </option>
#           <option title="Contains" value="CT">
#            CT
#           </option>
#           <option title="Does not Contain" value="NC">
#            NC
#           </option>
#           <option title="Contains all" value="CA">
#            CA
#           </option>
#           <option title="Contains any" value="CO">
#            CO
#           </option>
#           <option title="Starts with" value="SW">
#            SW
#           </option>
#           <option title="Does not Start with" value="NW">
#            NW
#           </option>
#          </select>
#          <input class="mrcinput" id="val_SEXCOP" name="val_SEXCOP" size="6" title="val_SEXCOP" type="text" value=""/>
#         </th>
#         <th align="center">
#          <select class="mrcselect relation" id="F_C_LI_RACECP" name="rls_RACECP">
#           <option title="Equal" value="EQ">
#            EQ
#           </option>
#           <option title="Not equal" value="NE">
#            NE
#           </option>
#           <option title="Greater than or equal" value="GE">
#            GE
#           </option>
#           <option title="Greater than" value="GT">
#            GT
#           </option>
#           <option title="Less than or equal" value="LE">
#            LE
#           </option>
#           <option title="Less than" value="LT">
#            LT
#           </option>
#           <option title="In the list" value="LS">
#            LS
#           </option>
#           <option title="Not in the list" value="NS">
#            NS
#           </option>
#           <option title="In the range" value="RG">
#            RG
#           </option>
#           <option title="Not in the range" value="NR">
#            NR
#           </option>
#           <option title="Contains" value="CT">
#            CT
#           </option>
#           <option title="Does not Contain" value="NC">
#            NC
#           </option>
#           <option title="Contains all" value="CA">
#            CA
#           </option>
#           <option title="Contains any" value="CO">
#            CO
#           </option>
#           <option title="Starts with" value="SW">
#            SW
#           </option>
#           <option title="Does not Start with" value="NW">
#            NW
#           </option>
#          </select>
#          <input class="mrcinput" id="val_RACECP" name="val_RACECP" size="6" title="val_RACECP" type="text" value=""/>
#         </th>
#         <th align="center">
#          <select class="mrcselect relation" id="F_C_LI_AGEBEP" name="rls_AGEBEP">
#           <option title="Equal" value="EQ">
#            EQ
#           </option>
#           <option title="Not equal" value="NE">
#            NE
#           </option>
#           <option title="Greater than or equal" value="GE">
#            GE
#           </option>
#           <option title="Greater than" value="GT">
#            GT
#           </option>
#           <option title="Less than or equal" value="LE">
#            LE
#           </option>
#           <option title="Less than" value="LT">
#            LT
#           </option>
#           <option title="In the list" value="LS">
#            LS
#           </option>
#           <option title="Not in the list" value="NS">
#            NS
#           </option>
#           <option title="In the range" value="RG">
#            RG
#           </option>
#           <option title="Not in the range" value="NR">
#            NR
#           </option>
#           <option title="Contains" value="CT">
#            CT
#           </option>
#           <option title="Does not Contain" value="NC">
#            NC
#           </option>
#           <option title="Contains all" value="CA">
#            CA
#           </option>
#           <option title="Contains any" value="CO">
#            CO
#           </option>
#           <option title="Starts with" value="SW">
#            SW
#           </option>
#           <option title="Does not Start with" value="NW">
#            NW
#           </option>
#          </select>
#          <input class="mrcinput" id="val_AGEBEP" name="val_AGEBEP" size="6" title="val_AGEBEP" type="text" value=""/>
#         </th>
#         <th align="center">
#          <select class="mrcselect relation" id="F_C_LI_CITYMP" name="rls_CITYMP">
#           <option title="Equal" value="EQ">
#            EQ
#           </option>
#           <option title="Not equal" value="NE">
#            NE
#           </option>
#           <option title="Greater than or equal" value="GE">
#            GE
#           </option>
#           <option title="Greater than" value="GT">
#            GT
#           </option>
#           <option title="Less than or equal" value="LE">
#            LE
#           </option>
#           <option title="Less than" value="LT">
#            LT
#           </option>
#           <option title="In the list" value="LS">
#            LS
#           </option>
#           <option title="Not in the list" value="NS">
#            NS
#           </option>
#           <option title="In the range" value="RG">
#            RG
#           </option>
#           <option title="Not in the range" value="NR">
#            NR
#           </option>
#           <option title="Contains" value="CT">
#            CT
#           </option>
#           <option title="Does not Contain" value="NC">
#            NC
#           </option>
#           <option title="Contains all" value="CA">
#            CA
#           </option>
#           <option title="Contains any" value="CO">
#            CO
#           </option>
#           <option title="Starts with" value="SW">
#            SW
#           </option>
#           <option title="Does not Start with" value="NW">
#            NW
#           </option>
#          </select>
#          <input class="mrcinput" id="val_CITYMP" name="val_CITYMP" size="6" title="val_CITYMP" type="text" value=""/>
#         </th>
#         <th align="center">
#          <select class="mrcselect relation" id="F_C_LI_STATEP" name="rls_STATEP">
#           <option title="Equal" value="EQ">
#            EQ
#           </option>
#           <option title="Not equal" value="NE">
#            NE
#           </option>
#           <option title="Greater than or equal" value="GE">
#            GE
#           </option>
#           <option title="Greater than" value="GT">
#            GT
#           </option>
#           <option title="Less than or equal" value="LE">
#            LE
#           </option>
#           <option title="Less than" value="LT">
#            LT
#           </option>
#           <option title="In the list" value="LS">
#            LS
#           </option>
#           <option title="Not in the list" value="NS">
#            NS
#           </option>
#           <option title="In the range" value="RG">
#            RG
#           </option>
#           <option title="Not in the range" value="NR">
#            NR
#           </option>
#           <option title="Contains" value="CT">
#            CT
#           </option>
#           <option title="Does not Contain" value="NC">
#            NC
#           </option>
#           <option title="Contains all" value="CA">
#            CA
#           </option>
#           <option title="Contains any" value="CO">
#            CO
#           </option>
#           <option title="Starts with" value="SW">
#            SW
#           </option>
#           <option title="Does not Start with" value="NW">
#            NW
#           </option>
#          </select>
#          <input class="mrcinput" id="val_STATEP" name="val_STATEP" size="6" title="val_STATEP" type="text" value=""/>
#         </th>
#         <th align="center">
#         </th>
#        </tr>
#        <!--  -->
#       </thead>
#       <!--END_ADVANCED_SEARCH-->
#       <tbody class="stripe" id="mrc_main_table">
#        <!--   -->
#        <tr class="odd">
#         <td class="one td_left" data-th="Last Name">
#          AARON
#         </td>
#         <td class="one td_left" data-th="First Name">
#          KEVIN
#         </td>
#         <td class="one td_left" data-th="Middle Name">
#          PHILLIP
#         </td>
#         <td class="one td_left" data-th="Sex">
#          M
#         </td>
#         <td class="one td_left" data-th="Race">
#          B
#         </td>
#         <td class="one td_right" data-th="Age">
#          23
#         </td>
#         <td class="one td_left" data-th="City">
#          COLUMBIA
#         </td>
#         <td class="one td_left" data-th="State">
#          MO
#         </td>
#         <td class="one td_left" data-th="">
#          <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=66343&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#           <i class="fa fa-large fa-fw fa-list-alt">
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!--   -->
#        <tr class="even">
#         <td class="two td_left" data-th="Last Name">
#          ACOSTA
#         </td>
#         <td class="two td_left" data-th="First Name">
#          VINCENT
#         </td>
#         <td class="two td_left" data-th="Middle Name">
#          DAVID
#         </td>
#         <td class="two td_left" data-th="Sex">
#          M
#         </td>
#         <td class="two td_left" data-th="Race">
#          W
#         </td>
#         <td class="two td_right" data-th="Age">
#          53
#         </td>
#         <td class="two td_left" data-th="City">
#          MEXICO
#         </td>
#         <td class="two td_left" data-th="State">
#          MO
#         </td>
#         <td class="two td_left" data-th="">
#          <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=22950&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#           <i class="fa fa-large fa-fw fa-list-alt">
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!--   -->
#        <tr class="odd">
#         <td class="one td_left" data-th="Last Name">
#          ACTON
#         </td>
#         <td class="one td_left" data-th="First Name">
#          ANTHONY
#         </td>
#         <td class="one td_left" data-th="Middle Name">
#          SEAN
#         </td>
#         <td class="one td_left" data-th="Sex">
#          M
#         </td>
#         <td class="one td_left" data-th="Race">
#          B
#         </td>
#         <td class="one td_right" data-th="Age">
#          26
#         </td>
#         <td class="one td_left" data-th="City">
#          COLUMBIA
#         </td>
#         <td class="one td_left" data-th="State">
#          MO
#         </td>
#         <td class="one td_left" data-th="">
#          <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=66619&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#           <i class="fa fa-large fa-fw fa-list-alt">
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!--   -->
#        <tr class="even">
#         <td class="two td_left" data-th="Last Name">
#          ADAM
#         </td>
#         <td class="two td_left" data-th="First Name">
#          OMER
#         </td>
#         <td class="two td_left" data-th="Middle Name">
#          SIRAJ
#         </td>
#         <td class="two td_left" data-th="Sex">
#          M
#         </td>
#         <td class="two td_left" data-th="Race">
#          B
#         </td>
#         <td class="two td_right" data-th="Age">
#          30
#         </td>
#         <td class="two td_left" data-th="City">
#          COLUMBIA
#         </td>
#         <td class="two td_left" data-th="State">
#          MO
#         </td>
#         <td class="two td_left" data-th="">
#          <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=77695&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#           <i class="fa fa-large fa-fw fa-list-alt">
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!--   -->
#        <tr class="odd">
#         <td class="one td_left" data-th="Last Name">
#          ADAMS
#         </td>
#         <td class="one td_left" data-th="First Name">
#          JEREMIAH
#         </td>
#         <td class="one td_left" data-th="Middle Name">
#          SETH
#         </td>
#         <td class="one td_left" data-th="Sex">
#          M
#         </td>
#         <td class="one td_left" data-th="Race">
#          W
#         </td>
#         <td class="one td_right" data-th="Age">
#          43
#         </td>
#         <td class="one td_left" data-th="City">
#          CENTRALIA
#         </td>
#         <td class="one td_left" data-th="State">
#          MO
#         </td>
#         <td class="one td_left" data-th="">
#          <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=23883&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#           <i class="fa fa-large fa-fw fa-list-alt">
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!--   -->
#        <tr class="even">
#         <td class="two td_left" data-th="Last Name">
#          ALEXANDER
#         </td>
#         <td class="two td_left" data-th="First Name">
#          BENJAMIN
#         </td>
#         <td class="two td_left" data-th="Middle Name">
#          FRANKLIN
#         </td>
#         <td class="two td_left" data-th="Sex">
#          M
#         </td>
#         <td class="two td_left" data-th="Race">
#          B
#         </td>
#         <td class="two td_right" data-th="Age">
#          23
#         </td>
#         <td class="two td_left" data-th="City">
#          COLUMBIA
#         </td>
#         <td class="two td_left" data-th="State">
#          MO
#         </td>
#         <td class="two td_left" data-th="">
#          <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=74927&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#           <i class="fa fa-large fa-fw fa-list-alt">
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!--   -->
#        <tr class="odd">
#         <td class="one td_left" data-th="Last Name">
#          ANDERSON
#         </td>
#         <td class="one td_left" data-th="First Name">
#          RICHARD
#         </td>
#         <td class="one td_left" data-th="Middle Name">
#          KENNETH
#         </td>
#         <td class="one td_left" data-th="Sex">
#          M
#         </td>
#         <td class="one td_left" data-th="Race">
#          B
#         </td>
#         <td class="one td_right" data-th="Age">
#          24
#         </td>
#         <td class="one td_left" data-th="City">
#          COLUMBIA
#         </td>
#         <td class="one td_left" data-th="State">
#          MO
#         </td>
#         <td class="one td_left" data-th="">
#          <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=66544&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#           <i class="fa fa-large fa-fw fa-list-alt">
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!--   -->
#        <tr class="even">
#         <td class="two td_left" data-th="Last Name">
#          ARCHAMBAULT
#         </td>
#         <td class="two td_left" data-th="First Name">
#          MARK
#         </td>
#         <td class="two td_left" data-th="Middle Name">
#          VINCENT
#         </td>
#         <td class="two td_left" data-th="Sex">
#          M
#         </td>
#         <td class="two td_left" data-th="Race">
#          W
#         </td>
#         <td class="two td_right" data-th="Age">
#          56
#         </td>
#         <td class="two td_left" data-th="City">
#          COLUMBIA
#         </td>
#         <td class="two td_left" data-th="State">
#          MO
#         </td>
#         <td class="two td_left" data-th="">
#          <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=76691&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#           <i class="fa fa-large fa-fw fa-list-alt">
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!--   -->
#        <tr class="odd">
#         <td class="one td_left" data-th="Last Name">
#          ARCHULETA
#         </td>
#         <td class="one td_left" data-th="First Name">
#          JUSTIN
#         </td>
#         <td class="one td_left" data-th="Middle Name">
#          LEE
#         </td>
#         <td class="one td_left" data-th="Sex">
#          M
#         </td>
#         <td class="one td_left" data-th="Race">
#          W
#         </td>
#         <td class="one td_right" data-th="Age">
#          37
#         </td>
#         <td class="one td_left" data-th="City">
#          COLUMBIA
#         </td>
#         <td class="one td_left" data-th="State">
#          MO
#         </td>
#         <td class="one td_left" data-th="">
#          <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=23834&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#           <i class="fa fa-large fa-fw fa-list-alt">
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!--   -->
#        <tr class="even">
#         <td class="two td_left" data-th="Last Name">
#          ARMSTRONG
#         </td>
#         <td class="two td_left" data-th="First Name">
#          EDWARD
#         </td>
#         <td class="two td_left" data-th="Middle Name">
#          MAHON
#         </td>
#         <td class="two td_left" data-th="Sex">
#          M
#         </td>
#         <td class="two td_left" data-th="Race">
#          B
#         </td>
#         <td class="two td_right" data-th="Age">
#          37
#         </td>
#         <td class="two td_left" data-th="City">
#          COLUMBIA
#         </td>
#         <td class="two td_left" data-th="State">
#          MO
#         </td>
#         <td class="two td_left" data-th="">
#          <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=63563&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#           <i class="fa fa-large fa-fw fa-list-alt">
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!--   -->
#        <tr class="odd">
#         <td class="one td_left" data-th="Last Name">
#          ATTERBERRY
#         </td>
#         <td class="one td_left" data-th="First Name">
#          JUSTIN
#         </td>
#         <td class="one td_left" data-th="Middle Name">
#          MICHAEL
#         </td>
#         <td class="one td_left" data-th="Sex">
#          M
#         </td>
#         <td class="one td_left" data-th="Race">
#          W
#         </td>
#         <td class="one td_right" data-th="Age">
#          27
#         </td>
#         <td class="one td_left" data-th="City">
#          HOLT SUMMIT
#         </td>
#         <td class="one td_left" data-th="State">
#          MO
#         </td>
#         <td class="one td_left" data-th="">
#          <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=77291&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#           <i class="fa fa-large fa-fw fa-list-alt">
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!--   -->
#        <tr class="even">
#         <td class="two td_left" data-th="Last Name">
#          BAKER
#         </td>
#         <td class="two td_left" data-th="First Name">
#          CHRISTOPHER
#         </td>
#         <td class="two td_left" data-th="Middle Name">
#          ALAN
#         </td>
#         <td class="two td_left" data-th="Sex">
#          M
#         </td>
#         <td class="two td_left" data-th="Race">
#          W
#         </td>
#         <td class="two td_right" data-th="Age">
#          28
#         </td>
#         <td class="two td_left" data-th="City">
#          COLUMBIA
#         </td>
#         <td class="two td_left" data-th="State">
#          MO
#         </td>
#         <td class="two td_left" data-th="">
#          <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=59254&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#           <i class="fa fa-large fa-fw fa-list-alt">
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!--   -->
#        <tr class="odd">
#         <td class="one td_left" data-th="Last Name">
#          BALDWIN
#         </td>
#         <td class="one td_left" data-th="First Name">
#          SAM
#         </td>
#         <td class="one td_left" data-th="Middle Name">
# ...
#   <td class="one td_left" data-th="First Name">
#    GEOFFREY
#   </td>
#   <td class="one td_left" data-th="Middle Name">
#    DARL
#   </td>
#   <td class="one td_left" data-th="Sex">
#    M
#   </td>
#   <td class="one td_left" data-th="Race">
#    W
#   </td>
#   <td class="one td_right" data-th="Age">
#    28
#   </td>
#   <td class="one td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="one td_left" data-th="State">
#    MO
#   </td>
#   <td class="one td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=55499&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="even">
#   <td class="two td_left" data-th="Last Name">
#    BURTON
#   </td>
#   <td class="two td_left" data-th="First Name">
#    HEIDI
#   </td>
#   <td class="two td_left" data-th="Middle Name">
#    SUE
#   </td>
#   <td class="two td_left" data-th="Sex">
#    F
#   </td>
#   <td class="two td_left" data-th="Race">
#    W
#   </td>
#   <td class="two td_right" data-th="Age">
#    39
#   </td>
#   <td class="two td_left" data-th="City">
#    HALLSVILLE
#   </td>
#   <td class="two td_left" data-th="State">
#    MO
#   </td>
#   <td class="two td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=46477&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="odd">
#   <td class="one td_left" data-th="Last Name">
#    BUSH
#   </td>
#   <td class="one td_left" data-th="First Name">
#    DEVON
#   </td>
#   <td class="one td_left" data-th="Middle Name">
#    ALBERT
#   </td>
#   <td class="one td_left" data-th="Sex">
#    M
#   </td>
#   <td class="one td_left" data-th="Race">
#    B
#   </td>
#   <td class="one td_right" data-th="Age">
#    22
#   </td>
#   <td class="one td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="one td_left" data-th="State">
#    MO
#   </td>
#   <td class="one td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=80868&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="even">
#   <td class="two td_left" data-th="Last Name">
#    BUTLER
#   </td>
#   <td class="two td_left" data-th="First Name">
#    JEMELL
#   </td>
#   <td class="two td_left" data-th="Middle Name">
#    DUPRUE
#   </td>
#   <td class="two td_left" data-th="Sex">
#    M
#   </td>
#   <td class="two td_left" data-th="Race">
#    B
#   </td>
#   <td class="two td_right" data-th="Age">
#    22
#   </td>
#   <td class="two td_left" data-th="City">
#    JEFFERSON CITY
#   </td>
#   <td class="two td_left" data-th="State">
#    MO
#   </td>
#   <td class="two td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=72107&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="odd">
#   <td class="one td_left" data-th="Last Name">
#    BYERS
#   </td>
#   <td class="one td_left" data-th="First Name">
#    NORISHA
#   </td>
#   <td class="one td_left" data-th="Middle Name">
#    NICOLE
#   </td>
#   <td class="one td_left" data-th="Sex">
#    F
#   </td>
#   <td class="one td_left" data-th="Race">
#    B
#   </td>
#   <td class="one td_right" data-th="Age">
#    24
#   </td>
#   <td class="one td_left" data-th="City">
#    FULTON
#   </td>
#   <td class="one td_left" data-th="State">
#    MO
#   </td>
#   <td class="one td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=80682&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="even">
#   <td class="two td_left" data-th="Last Name">
#    CANFIELD
#   </td>
#   <td class="two td_left" data-th="First Name">
#    NATHAN
#   </td>
#   <td class="two td_left" data-th="Middle Name">
#    EDWARD
#   </td>
#   <td class="two td_left" data-th="Sex">
#    M
#   </td>
#   <td class="two td_left" data-th="Race">
#    W
#   </td>
#   <td class="two td_right" data-th="Age">
#    36
#   </td>
#   <td class="two td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="two td_left" data-th="State">
#    MO
#   </td>
#   <td class="two td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=79636&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="odd">
#   <td class="one td_left" data-th="Last Name">
#    CARPENTER
#   </td>
#   <td class="one td_left" data-th="First Name">
#    KALINDA
#   </td>
#   <td class="one td_left" data-th="Middle Name">
#    MARIE
#   </td>
#   <td class="one td_left" data-th="Sex">
#    F
#   </td>
#   <td class="one td_left" data-th="Race">
#    B
#   </td>
#   <td class="one td_right" data-th="Age">
#    33
#   </td>
#   <td class="one td_left" data-th="City">
#    CENTRALIA
#   </td>
#   <td class="one td_left" data-th="State">
#    MO
#   </td>
#   <td class="one td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=69298&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="even">
#   <td class="two td_left" data-th="Last Name">
#    CARTER
#   </td>
#   <td class="two td_left" data-th="First Name">
#    DARIAN
#   </td>
#   <td class="two td_left" data-th="Middle Name">
#    MAURICE
#   </td>
#   <td class="two td_left" data-th="Sex">
#    M
#   </td>
#   <td class="two td_left" data-th="Race">
#    B
#   </td>
#   <td class="two td_right" data-th="Age">
#    25
#   </td>
#   <td class="two td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="two td_left" data-th="State">
#    MO
#   </td>
#   <td class="two td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=56088&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="odd">
#   <td class="one td_left" data-th="Last Name">
#    CAUDLE
#   </td>
#   <td class="one td_left" data-th="First Name">
#    CHRISTINE
#   </td>
#   <td class="one td_left" data-th="Middle Name">
#    ELIZABETH
#   </td>
#   <td class="one td_left" data-th="Sex">
#    F
#   </td>
#   <td class="one td_left" data-th="Race">
#    W
#   </td>
#   <td class="one td_right" data-th="Age">
#    32
#   </td>
#   <td class="one td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="one td_left" data-th="State">
#    MO
#   </td>
#   <td class="one td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=41652&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="even">
#   <td class="two td_left" data-th="Last Name">
#    CHILTON-GATTEN
#   </td>
#   <td class="two td_left" data-th="First Name">
#    CANDACE
#   </td>
#   <td class="two td_left" data-th="Middle Name">
#    ALMIRA
#   </td>
#   <td class="two td_left" data-th="Sex">
#    F
#   </td>
#   <td class="two td_left" data-th="Race">
#    W
#   </td>
#   <td class="two td_right" data-th="Age">
#    35
#   </td>
#   <td class="two td_left" data-th="City">
#    FULTON
#   </td>
#   <td class="two td_left" data-th="State">
#    MO
#   </td>
#   <td class="two td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=80881&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="odd">
#   <td class="one td_left" data-th="Last Name">
#    CHRISTMAS
#   </td>
#   <td class="one td_left" data-th="First Name">
#    JUSTIN
#   </td>
#   <td class="one td_left" data-th="Middle Name">
#    LYNN
#   </td>
#   <td class="one td_left" data-th="Sex">
#    M
#   </td>
#   <td class="one td_left" data-th="Race">
#    W
#   </td>
#   <td class="one td_right" data-th="Age">
#    41
#   </td>
#   <td class="one td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="one td_left" data-th="State">
#    MO
#   </td>
#   <td class="one td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=24788&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="even">
#   <td class="two td_left" data-th="Last Name">
#    CLARK
#   </td>
#   <td class="two td_left" data-th="First Name">
#    THOMAS
#   </td>
#   <td class="two td_left" data-th="Middle Name">
#    EARL
#   </td>
#   <td class="two td_left" data-th="Sex">
#    M
#   </td>
#   <td class="two td_left" data-th="Race">
#    B
#   </td>
#   <td class="two td_right" data-th="Age">
#    64
#   </td>
#   <td class="two td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="two td_left" data-th="State">
#    MO
#   </td>
#   <td class="two td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=78312&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="odd">
#   <td class="one td_left" data-th="Last Name">
#    COCO
#   </td>
#   <td class="one td_left" data-th="First Name">
#    DREW
#   </td>
#   <td class="one td_left" data-th="Middle Name">
#    PATRICK
#   </td>
#   <td class="one td_left" data-th="Sex">
#    M
#   </td>
#   <td class="one td_left" data-th="Race">
#    W
#   </td>
#   <td class="one td_right" data-th="Age">
#    37
#   </td>
#   <td class="one td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="one td_left" data-th="State">
#    MO
#   </td>
#   <td class="one td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=35949&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="even">
#   <td class="two td_left" data-th="Last Name">
#    COLLINS
#   </td>
#   <td class="two td_left" data-th="First Name">
#    MICHAEL
#   </td>
#   <td class="two td_left" data-th="Middle Name">
#    JAMES
#   </td>
#   <td class="two td_left" data-th="Sex">
#    M
#   </td>
#   <td class="two td_left" data-th="Race">
#    W
#   </td>
#   <td class="two td_right" data-th="Age">
#    21
#   </td>
#   <td class="two td_left" data-th="City">
#    FULTON
#   </td>
#   <td class="two td_left" data-th="State">
#    MO
#   </td>
#   <td class="two td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=76466&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="odd">
#   <td class="one td_left" data-th="Last Name">
#    COMMANDER
#   </td>
#   <td class="one td_left" data-th="First Name">
#    JAVANTE
#   </td>
#   <td class="one td_left" data-th="Middle Name">
#    BRUCE
#   </td>
#   <td class="one td_left" data-th="Sex">
#    M
#   </td>
#   <td class="one td_left" data-th="Race">
#    B
#   </td>
#   <td class="one td_right" data-th="Age">
#    23
#   </td>
#   <td class="one td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="one td_left" data-th="State">
#    MO
#   </td>
#   <td class="one td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=68940&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="even">
#   <td class="two td_left" data-th="Last Name">
#    COX
#   </td>
#   <td class="two td_left" data-th="First Name">
#    JAQUE
#   </td>
#   <td class="two td_left" data-th="Middle Name">
#    DERON
#   </td>
#   <td class="two td_left" data-th="Sex">
#    M
#   </td>
#   <td class="two td_left" data-th="Race">
#    B
#   </td>
#   <td class="two td_right" data-th="Age">
#    28
#   </td>
#   <td class="two td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="two td_left" data-th="State">
#    MO
#   </td>
#   <td class="two td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=68391&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="odd">
#   <td class="one td_left" data-th="Last Name">
#    CRAIN
#   </td>
#   <td class="one td_left" data-th="First Name">
#    THOMAS
#   </td>
#   <td class="one td_left" data-th="Middle Name">
#    RAY
#   </td>
#   <td class="one td_left" data-th="Sex">
#    M
#   </td>
#   <td class="one td_left" data-th="Race">
#    W
#   </td>
#   <td class="one td_right" data-th="Age">
#    48
#   </td>
#   <td class="one td_left" data-th="City">
#    BRIGHTON
#   </td>
#   <td class="one td_left" data-th="State">
#    TN
#   </td>
#   <td class="one td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=80735&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="even">
#   <td class="two td_left" data-th="Last Name">
#    CRAWLEY
#   </td>
#   <td class="two td_left" data-th="First Name">
#    EDDIE
#   </td>
#   <td class="two td_left" data-th="Middle Name">
#    HUGHES
#   </td>
#   <td class="two td_left" data-th="Sex">
#    M
#   </td>
#   <td class="two td_left" data-th="Race">
#    B
#   </td>
#   <td class="two td_right" data-th="Age">
#    64
#   </td>
#   <td class="two td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="two td_left" data-th="State">
#    MO
#   </td>
#   <td class="two td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=10979&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="tr-paging">
#   <th class="th_left paging_row bottomPaging" colspan="93">
#    Detainee Count: 241
#    <div class="pagination pagination-right fixed-pagination" style="margin-left: 2em;">
#     <ul>
#      <li>
#       <a class="page-button" data-pagetype="btn_top" href="javascript:void(0)">
#        <i class="fa fa-angle-double-left fa-large">
#        </i>
#       </a>
#      </li>
#      <li>
#       <a class="page-button" data-pagetype="btn_prev" href="javascript:void(0)">
#        <i class="fa fa-angle-left fa-large">
#        </i>
#       </a>
#      </li>
#      <li class="disabled">
#       <a href="#">
#        Page 1 of 5
#       </a>
#      </li>
#      <li>
#       <a class="page-button" data-pagetype="btn_next" href="javascript:void(0)">
#        <i class="fa fa-angle-right fa-large">
#        </i>
#       </a>
#      </li>
#      <li>
#       <a class="page-button" data-pagetype="btn_btmm" href="javascript:void(0)">
#        <i class="fa fa-angle-double-right fa-large">
#        </i>
#       </a>
#      </li>
#     </ul>
#    </div>
#   </th>
#  </tr>
# </tbody>

# %%
table = soup.find('tbody', attrs={'class': 'stripe'})
print(table.prettify())
# Out:
# <tbody class="stripe" id="mrc_main_table">
#  <!--   -->
#  <tr class="odd">
#   <td class="one td_left" data-th="Last Name">
#    AARON
#   </td>
#   <td class="one td_left" data-th="First Name">
#    KEVIN
#   </td>
#   <td class="one td_left" data-th="Middle Name">
#    PHILLIP
#   </td>
#   <td class="one td_left" data-th="Sex">
#    M
#   </td>
#   <td class="one td_left" data-th="Race">
#    B
#   </td>
#   <td class="one td_right" data-th="Age">
#    23
#   </td>
#   <td class="one td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="one td_left" data-th="State">
#    MO
#   </td>
#   <td class="one td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=66343&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="even">
#   <td class="two td_left" data-th="Last Name">
#    ACOSTA
#   </td>
#   <td class="two td_left" data-th="First Name">
#    VINCENT
#   </td>
#   <td class="two td_left" data-th="Middle Name">
#    DAVID
#   </td>
#   <td class="two td_left" data-th="Sex">
#    M
#   </td>
#   <td class="two td_left" data-th="Race">
#    W
#   </td>
#   <td class="two td_right" data-th="Age">
#    53
#   </td>
#   <td class="two td_left" data-th="City">
#    MEXICO
#   </td>
#   <td class="two td_left" data-th="State">
#    MO
#   </td>
#   <td class="two td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=22950&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="odd">
#   <td class="one td_left" data-th="Last Name">
#    ACTON
#   </td>
#   <td class="one td_left" data-th="First Name">
#    ANTHONY
#   </td>
#   <td class="one td_left" data-th="Middle Name">
#    SEAN
#   </td>
#   <td class="one td_left" data-th="Sex">
#    M
#   </td>
#   <td class="one td_left" data-th="Race">
#    B
#   </td>
#   <td class="one td_right" data-th="Age">
#    26
#   </td>
#   <td class="one td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="one td_left" data-th="State">
#    MO
#   </td>
#   <td class="one td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=66619&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="even">
#   <td class="two td_left" data-th="Last Name">
#    ADAM
#   </td>
#   <td class="two td_left" data-th="First Name">
#    OMER
#   </td>
#   <td class="two td_left" data-th="Middle Name">
#    SIRAJ
#   </td>
#   <td class="two td_left" data-th="Sex">
#    M
#   </td>
#   <td class="two td_left" data-th="Race">
#    B
#   </td>
#   <td class="two td_right" data-th="Age">
#    30
#   </td>
#   <td class="two td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="two td_left" data-th="State">
#    MO
#   </td>
#   <td class="two td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=77695&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="odd">
#   <td class="one td_left" data-th="Last Name">
#    ADAMS
#   </td>
#   <td class="one td_left" data-th="First Name">
#    JEREMIAH
#   </td>
#   <td class="one td_left" data-th="Middle Name">
#    SETH
#   </td>
#   <td class="one td_left" data-th="Sex">
#    M
#   </td>
#   <td class="one td_left" data-th="Race">
#    W
#   </td>
#   <td class="one td_right" data-th="Age">
#    43
#   </td>
#   <td class="one td_left" data-th="City">
#    CENTRALIA
#   </td>
#   <td class="one td_left" data-th="State">
#    MO
#   </td>
#   <td class="one td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=23883&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="even">
#   <td class="two td_left" data-th="Last Name">
#    ALEXANDER
#   </td>
#   <td class="two td_left" data-th="First Name">
#    BENJAMIN
#   </td>
#   <td class="two td_left" data-th="Middle Name">
#    FRANKLIN
#   </td>
#   <td class="two td_left" data-th="Sex">
#    M
#   </td>
#   <td class="two td_left" data-th="Race">
#    B
#   </td>
#   <td class="two td_right" data-th="Age">
#    23
#   </td>
#   <td class="two td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="two td_left" data-th="State">
#    MO
#   </td>
#   <td class="two td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=74927&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="odd">
#   <td class="one td_left" data-th="Last Name">
#    ANDERSON
#   </td>
#   <td class="one td_left" data-th="First Name">
#    RICHARD
#   </td>
#   <td class="one td_left" data-th="Middle Name">
#    KENNETH
#   </td>
#   <td class="one td_left" data-th="Sex">
#    M
#   </td>
#   <td class="one td_left" data-th="Race">
#    B
#   </td>
#   <td class="one td_right" data-th="Age">
#    24
#   </td>
#   <td class="one td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="one td_left" data-th="State">
#    MO
#   </td>
#   <td class="one td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=66544&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="even">
#   <td class="two td_left" data-th="Last Name">
#    ARCHAMBAULT
#   </td>
#   <td class="two td_left" data-th="First Name">
#    MARK
#   </td>
#   <td class="two td_left" data-th="Middle Name">
#    VINCENT
#   </td>
#   <td class="two td_left" data-th="Sex">
#    M
#   </td>
#   <td class="two td_left" data-th="Race">
#    W
#   </td>
#   <td class="two td_right" data-th="Age">
#    56
#   </td>
#   <td class="two td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="two td_left" data-th="State">
#    MO
#   </td>
#   <td class="two td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=76691&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="odd">
#   <td class="one td_left" data-th="Last Name">
#    ARCHULETA
#   </td>
#   <td class="one td_left" data-th="First Name">
#    JUSTIN
#   </td>
#   <td class="one td_left" data-th="Middle Name">
#    LEE
#   </td>
#   <td class="one td_left" data-th="Sex">
#    M
#   </td>
#   <td class="one td_left" data-th="Race">
#    W
#   </td>
#   <td class="one td_right" data-th="Age">
#    37
#   </td>
#   <td class="one td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="one td_left" data-th="State">
#    MO
#   </td>
#   <td class="one td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=23834&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="even">
#   <td class="two td_left" data-th="Last Name">
#    ARMSTRONG
#   </td>
#   <td class="two td_left" data-th="First Name">
#    EDWARD
#   </td>
#   <td class="two td_left" data-th="Middle Name">
#    MAHON
#   </td>
#   <td class="two td_left" data-th="Sex">
#    M
#   </td>
#   <td class="two td_left" data-th="Race">
#    B
#   </td>
#   <td class="two td_right" data-th="Age">
#    37
#   </td>
#   <td class="two td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="two td_left" data-th="State">
#    MO
#   </td>
#   <td class="two td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=63563&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="odd">
#   <td class="one td_left" data-th="Last Name">
#    ATTERBERRY
#   </td>
#   <td class="one td_left" data-th="First Name">
#    JUSTIN
#   </td>
#   <td class="one td_left" data-th="Middle Name">
#    MICHAEL
#   </td>
#   <td class="one td_left" data-th="Sex">
#    M
#   </td>
#   <td class="one td_left" data-th="Race">
#    W
#   </td>
#   <td class="one td_right" data-th="Age">
#    27
#   </td>
#   <td class="one td_left" data-th="City">
#    HOLT SUMMIT
#   </td>
#   <td class="one td_left" data-th="State">
#    MO
#   </td>
#   <td class="one td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=77291&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="even">
#   <td class="two td_left" data-th="Last Name">
#    BAKER
#   </td>
#   <td class="two td_left" data-th="First Name">
#    CHRISTOPHER
#   </td>
#   <td class="two td_left" data-th="Middle Name">
#    ALAN
#   </td>
#   <td class="two td_left" data-th="Sex">
#    M
#   </td>
#   <td class="two td_left" data-th="Race">
#    W
#   </td>
#   <td class="two td_right" data-th="Age">
#    28
#   </td>
#   <td class="two td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="two td_left" data-th="State">
#    MO
#   </td>
#   <td class="two td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=59254&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="odd">
#   <td class="one td_left" data-th="Last Name">
#    BALDWIN
#   </td>
#   <td class="one td_left" data-th="First Name">
#    SAM
#   </td>
#   <td class="one td_left" data-th="Middle Name">
#   </td>
#   <td class="one td_left" data-th="Sex">
#    M
#   </td>
#   <td class="one td_left" data-th="Race">
#    B
#   </td>
#   <td class="one td_right" data-th="Age">
#    26
#   </td>
#   <td class="one td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="one td_left" data-th="State">
#    MO
#   </td>
#   <td class="one td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=57471&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="even">
#   <td class="two td_left" data-th="Last Name">
#    BARBERO
#   </td>
#   <td class="two td_left" data-th="First Name">
#    CASEY
#   </td>
#   <td class="two td_left" data-th="Middle Name">
#    TYLER
#   </td>
#   <td class="two td_left" data-th="Sex">
#    M
#   </td>
#   <td class="two td_left" data-th="Race">
#    W
#   </td>
#   <td class="two td_right" data-th="Age">
#    28
#   </td>
#   <td class="two td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="two td_left" data-th="State">
#    MO
#   </td>
#   <td class="two td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=50635&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="odd">
#   <td class="one td_left" data-th="Last Name">
#    BARNES
#   </td>
#   <td class="one td_left" data-th="First Name">
#    DARIN
#   </td>
#   <td class="one td_left" data-th="Middle Name">
#    WAYNE
#   </td>
#   <td class="one td_left" data-th="Sex">
#    M
#   </td>
#   <td class="one td_left" data-th="Race">
#    W
#   </td>
#   <td class="one td_right" data-th="Age">
#    33
#   </td>
#   <td class="one td_left" data-th="City">
#    MOBERLY
#   </td>
#   <td class="one td_left" data-th="State">
#    MO
#   </td>
#   <td class="one td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=77513&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="even">
#   <td class="two td_left" data-th="Last Name">
#    BARNHART
#   </td>
#   <td class="two td_left" data-th="First Name">
#    CHRIS
#   </td>
#   <td class="two td_left" data-th="Middle Name">
#    MICHAEL
#   </td>
#   <td class="two td_left" data-th="Sex">
#    M
#   </td>
#   <td class="two td_left" data-th="Race">
#    W
#   </td>
#   <td class="two td_right" data-th="Age">
#    28
#   </td>
#   <td class="two td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="two td_left" data-th="State">
#    MO
#   </td>
#   <td class="two td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=56348&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="odd">
#   <td class="one td_left" data-th="Last Name">
#    BEARS
#   </td>
#   <td class="one td_left" data-th="First Name">
#    JARED
#   </td>
#   <td class="one td_left" data-th="Middle Name">
#    ANTHONY
#   </td>
#   <td class="one td_left" data-th="Sex">
#    M
#   </td>
#   <td class="one td_left" data-th="Race">
#    W
#   </td>
#   <td class="one td_right" data-th="Age">
#    19
#   </td>
#   <td class="one td_left" data-th="City">
#    BUCKNER
#   </td>
#   <td class="one td_left" data-th="State">
#    MO
#   </td>
#   <td class="one td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=80333&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="even">
#   <td class="two td_left" data-th="Last Name">
#    BEL
#   </td>
#   <td class="two td_left" data-th="First Name">
#    ROBERT
#   </td>
#   <td class="two td_left" data-th="Middle Name">
#    ANTHONY
#   </td>
#   <td class="two td_left" data-th="Sex">
#    M
#   </td>
#   <td class="two td_left" data-th="Race">
#    W
#   </td>
#   <td class="two td_right" data-th="Age">
#    34
#   </td>
#   <td class="two td_left" data-th="City">
#    BATON ROUGE
#   </td>
#   <td class="two td_left" data-th="State">
#    LA
#   </td>
#   <td class="two td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=75600&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="odd">
#   <td class="one td_left" data-th="Last Name">
#    BENEDETTI
#   </td>
#   <td class="one td_left" data-th="First Name">
#    FRANK
#   </td>
#   <td class="one td_left" data-th="Middle Name">
#    DOMINICK
#   </td>
#   <td class="one td_left" data-th="Sex">
#    M
#   </td>
#   <td class="one td_left" data-th="Race">
#    W
#   </td>
#   <td class="one td_right" data-th="Age">
#    29
#   </td>
#   <td class="one td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="one td_left" data-th="State">
#    MO
#   </td>
#   <td class="one td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=79913&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="even">
#   <td class="two td_left" data-th="Last Name">
#    BERARDI
#   </td>
#   <td class="two td_left" data-th="First Name">
#    DEBORAH
#   </td>
#   <td class="two td_left" data-th="Middle Name">
#    EVA
#   </td>
#   <td class="two td_left" data-th="Sex">
#    F
#   </td>
#   <td class="two td_left" data-th="Race">
#    W
#   </td>
#   <td class="two td_right" data-th="Age">
#    56
#   </td>
#   <td class="two td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="two td_left" data-th="State">
#    MO
#   </td>
#   <td class="two td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=78005&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="odd">
#   <td class="one td_left" data-th="Last Name">
#    BETTS
#   </td>
#   <td class="one td_left" data-th="First Name">
#    LAWRENCE
#   </td>
#   <td class="one td_left" data-th="Middle Name">
#    SHERRON
#   </td>
#   <td class="one td_left" data-th="Sex">
#    M
#   </td>
#   <td class="one td_left" data-th="Race">
#    B
#   </td>
#   <td class="one td_right" data-th="Age">
#    43
#   </td>
#   <td class="one td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="one td_left" data-th="State">
#    MO
#   </td>
#   <td class="one td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=43249&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="even">
#   <td class="two td_left" data-th="Last Name">
#    BLACK
#   </td>
#   <td class="two td_left" data-th="First Name">
#    JAMIE
#   </td>
#   <td class="two td_left" data-th="Middle Name">
#    LEE
#   </td>
#   <td class="two td_left" data-th="Sex">
#    F
#   </td>
#   <td class="two td_left" data-th="Race">
#    W
#   </td>
#   <td class="two td_right" data-th="Age">
#    38
#   </td>
#   <td class="two td_left" data-th="City">
#    LOS ANGELES
#   </td>
#   <td class="two td_left" data-th="State">
#    CA
#   </td>
#   <td class="two td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=80505&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="odd">
#   <td class="one td_left" data-th="Last Name">
#    BLAND
#   </td>
#   <td class="one td_left" data-th="First Name">
#    RANDY
#   </td>
#   <td class="one td_left" data-th="Middle Name">
#    LAMONT
#   </td>
#   <td class="one td_left" data-th="Sex">
#    M
#   </td>
#   <td class="one td_left" data-th="Race">
#    B
#   </td>
#   <td class="one td_right" data-th="Age">
#    23
#   </td>
#   <td class="one td_left" data-th="City">
#    SPRINGFIELD
#   </td>
#   <td class="one td_left" data-th="State">
#    MO
#   </td>
#   <td class="one td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=65798&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="even">
#   <td class="two td_left" data-th="Last Name">
#    BOSS
#   </td>
#   <td class="two td_left" data-th="First Name">
#    JAFARI
#   </td>
#   <td class="two td_left" data-th="Middle Name">
#    RASHIDI
#   </td>
#   <td class="two td_left" data-th="Sex">
#    M
#   </td>
#   <td class="two td_left" data-th="Race">
#    B
#   </td>
#   <td class="two td_right" data-th="Age">
#    34
#   </td>
#   <td class="two td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="two td_left" data-th="State">
#    MO
#   </td>
#   <td class="two td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=60725&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="odd">
#   <td class="one td_left" data-th="Last Name">
#    BRADLEY
#   </td>
#   <td class="one td_left" data-th="First Name">
#    JAMIE
#   </td>
#   <td class="one td_left" data-th="Middle Name">
#    MICHELLE
#   </td>
#   <td class="one td_left" data-th="Sex">
#    F
#   </td>
#   <td class="one td_left" data-th="Race">
#    W
#   </td>
#   <td class="one td_right" data-th="Age">
#    33
#   </td>
#   <td class="one td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="one td_left" data-th="State">
#    MO
#   </td>
#   <td class="one td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=44762&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="even">
#   <td class="two td_left" data-th="Last Name">
#    BRANCH
#   </td>
#   <td class="two td_left" data-th="First Name">
#    JASON
#   </td>
#   <td class="two td_left" data-th="Middle Name">
#    STEVEN
#   </td>
#   <td class="two td_left" data-th="Sex">
#    M
#   </td>
#   <td class="two td_left" data-th="Race">
#    W
#   </td>
#   <td class="two td_right" data-th="Age">
#    41
#   </td>
#   <td class="two td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="two td_left" data-th="State">
#    MO
#   </td>
#   <td class="two td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=57402&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="odd">
#   <td class="one td_left" data-th="Last Name">
#    BRILL
#   </td>
#   <td class="one td_left" data-th="First Name">
#    BRANDON
#   </td>
#   <td class="one td_left" data-th="Middle Name">
#    NICHOLAS
#   </td>
#   <td class="one td_left" data-th="Sex">
#    M
#   </td>
#   <td class="one td_left" data-th="Race">
#    W
#   </td>
#   <td class="one td_right" data-th="Age">
#    26
#   </td>
#   <td class="one td_left" data-th="City">
#    CLARK
#   </td>
#   <td class="one td_left" data-th="State">
#    MO
#   </td>
#   <td class="one td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=60089&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="even">
#   <td class="two td_left" data-th="Last Name">
#    BROOKINS
#   </td>
#   <td class="two td_left" data-th="First Name">
#    GARY
#   </td>
#   <td class="two td_left" data-th="Middle Name">
#    LAREN
#   </td>
#   <td class="two td_left" data-th="Sex">
#    M
#   </td>
#   <td class="two td_left" data-th="Race">
#    B
#   </td>
#   <td class="two td_right" data-th="Age">
#    60
#   </td>
#   <td class="two td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="two td_left" data-th="State">
#    MO
#   </td>
#   <td class="two td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=9940&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="odd">
#   <td class="one td_left" data-th="Last Name">
#    BROWN
#   </td>
#   <td class="one td_left" data-th="First Name">
#    BARRY
#   </td>
#   <td class="one td_left" data-th="Middle Name">
#    RONELL
#   </td>
#   <td class="one td_left" data-th="Sex">
#    M
#   </td>
#   <td class="one td_left" data-th="Race">
#    B
#   </td>
#   <td class="one td_right" data-th="Age">
#    31
#   </td>
#   <td class="one td_left" data-th="City">
#    FLORISSANT
#   </td>
#   <td class="one td_left" data-th="State">
#    MO
#   </td>
#   <td class="one td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=80297&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="even">
#   <td class="two td_left" data-th="Last Name">
#    BROWN
#   </td>
#   <td class="two td_left" data-th="First Name">
#    JEREMIAH
#   </td>
#   <td class="two td_left" data-th="Middle Name">
#    EZEKIEL
#   </td>
#   <td class="two td_left" data-th="Sex">
#    M
#   </td>
#   <td class="two td_left" data-th="Race">
#    B
#   </td>
#   <td class="two td_right" data-th="Age">
#    33
#   </td>
#   <td class="two td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="two td_left" data-th="State">
#    MO
#   </td>
#   <td class="two td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=37899&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="odd">
#   <td class="one td_left" data-th="Last Name">
#    BRYANT
#   </td>
#   <td class="one td_left" data-th="First Name">
#    JASON
#   </td>
#   <td class="one td_left" data-th="Middle Name">
#    KENNETH-LEE
#   </td>
#   <td class="one td_left" data-th="Sex">
#    M
#   </td>
#   <td class="one td_left" data-th="Race">
#    B
#   </td>
#   <td class="one td_right" data-th="Age">
#    17
#   </td>
#   <td class="one td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="one td_left" data-th="State">
#    MO
#   </td>
#   <td class="one td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=80581&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="even">
#   <td class="two td_left" data-th="Last Name">
#    BUNTYN
#   </td>
#   <td class="two td_left" data-th="First Name">
#    JOSHUA
#   </td>
#   <td class="two td_left" data-th="Middle Name">
#    LACOY
#   </td>
#   <td class="two td_left" data-th="Sex">
#    M
#   </td>
#   <td class="two td_left" data-th="Race">
#    B
#   </td>
#   <td class="two td_right" data-th="Age">
#    25
#   </td>
#   <td class="two td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="two td_left" data-th="State">
#    MO
#   </td>
#   <td class="two td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=79524&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="odd">
#   <td class="one td_left" data-th="Last Name">
#    BURRIS
#   </td>
#   <td class="one td_left" data-th="First Name">
#    GEOFFREY
#   </td>
#   <td class="one td_left" data-th="Middle Name">
#    DARL
#   </td>
#   <td class="one td_left" data-th="Sex">
#    M
#   </td>
#   <td class="one td_left" data-th="Race">
#    W
#   </td>
#   <td class="one td_right" data-th="Age">
#    28
#   </td>
#   <td class="one td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="one td_left" data-th="State">
#    MO
#   </td>
#   <td class="one td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=55499&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="even">
#   <td class="two td_left" data-th="Last Name">
#    BURTON
#   </td>
#   <td class="two td_left" data-th="First Name">
#    HEIDI
#   </td>
#   <td class="two td_left" data-th="Middle Name">
#    SUE
#   </td>
#   <td class="two td_left" data-th="Sex">
#    F
#   </td>
#   <td class="two td_left" data-th="Race">
#    W
#   </td>
#   <td class="two td_right" data-th="Age">
#    39
#   </td>
#   <td class="two td_left" data-th="City">
#    HALLSVILLE
#   </td>
#   <td class="two td_left" data-th="State">
#    MO
#   </td>
#   <td class="two td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=46477&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="odd">
#   <td class="one td_left" data-th="Last Name">
#    BUSH
#   </td>
#   <td class="one td_left" data-th="First Name">
#    DEVON
#   </td>
#   <td class="one td_left" data-th="Middle Name">
#    ALBERT
#   </td>
#   <td class="one td_left" data-th="Sex">
#    M
#   </td>
#   <td class="one td_left" data-th="Race">
#    B
#   </td>
#   <td class="one td_right" data-th="Age">
#    22
#   </td>
#   <td class="one td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="one td_left" data-th="State">
#    MO
#   </td>
#   <td class="one td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=80868&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="even">
#   <td class="two td_left" data-th="Last Name">
#    BUTLER
#   </td>
#   <td class="two td_left" data-th="First Name">
#    JEMELL
#   </td>
#   <td class="two td_left" data-th="Middle Name">
#    DUPRUE
#   </td>
#   <td class="two td_left" data-th="Sex">
#    M
#   </td>
#   <td class="two td_left" data-th="Race">
#    B
#   </td>
#   <td class="two td_right" data-th="Age">
#    22
#   </td>
#   <td class="two td_left" data-th="City">
#    JEFFERSON CITY
#   </td>
#   <td class="two td_left" data-th="State">
#    MO
#   </td>
#   <td class="two td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=72107&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="odd">
#   <td class="one td_left" data-th="Last Name">
#    BYERS
#   </td>
#   <td class="one td_left" data-th="First Name">
#    NORISHA
#   </td>
#   <td class="one td_left" data-th="Middle Name">
#    NICOLE
#   </td>
#   <td class="one td_left" data-th="Sex">
#    F
#   </td>
#   <td class="one td_left" data-th="Race">
#    B
#   </td>
#   <td class="one td_right" data-th="Age">
#    24
#   </td>
#   <td class="one td_left" data-th="City">
#    FULTON
#   </td>
#   <td class="one td_left" data-th="State">
#    MO
#   </td>
#   <td class="one td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=80682&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="even">
#   <td class="two td_left" data-th="Last Name">
#    CANFIELD
#   </td>
#   <td class="two td_left" data-th="First Name">
#    NATHAN
#   </td>
#   <td class="two td_left" data-th="Middle Name">
#    EDWARD
#   </td>
#   <td class="two td_left" data-th="Sex">
#    M
#   </td>
#   <td class="two td_left" data-th="Race">
#    W
#   </td>
#   <td class="two td_right" data-th="Age">
#    36
#   </td>
#   <td class="two td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="two td_left" data-th="State">
#    MO
#   </td>
#   <td class="two td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=79636&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="odd">
#   <td class="one td_left" data-th="Last Name">
#    CARPENTER
#   </td>
#   <td class="one td_left" data-th="First Name">
#    KALINDA
#   </td>
#   <td class="one td_left" data-th="Middle Name">
#    MARIE
#   </td>
#   <td class="one td_left" data-th="Sex">
#    F
#   </td>
#   <td class="one td_left" data-th="Race">
#    B
#   </td>
#   <td class="one td_right" data-th="Age">
#    33
#   </td>
#   <td class="one td_left" data-th="City">
#    CENTRALIA
#   </td>
#   <td class="one td_left" data-th="State">
#    MO
#   </td>
#   <td class="one td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=69298&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="even">
#   <td class="two td_left" data-th="Last Name">
#    CARTER
#   </td>
#   <td class="two td_left" data-th="First Name">
#    DARIAN
#   </td>
#   <td class="two td_left" data-th="Middle Name">
#    MAURICE
#   </td>
#   <td class="two td_left" data-th="Sex">
#    M
#   </td>
#   <td class="two td_left" data-th="Race">
#    B
#   </td>
#   <td class="two td_right" data-th="Age">
#    25
#   </td>
#   <td class="two td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="two td_left" data-th="State">
#    MO
#   </td>
#   <td class="two td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=56088&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="odd">
#   <td class="one td_left" data-th="Last Name">
#    CAUDLE
#   </td>
#   <td class="one td_left" data-th="First Name">
#    CHRISTINE
#   </td>
#   <td class="one td_left" data-th="Middle Name">
#    ELIZABETH
#   </td>
#   <td class="one td_left" data-th="Sex">
#    F
#   </td>
#   <td class="one td_left" data-th="Race">
#    W
#   </td>
#   <td class="one td_right" data-th="Age">
#    32
#   </td>
#   <td class="one td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="one td_left" data-th="State">
#    MO
#   </td>
#   <td class="one td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=41652&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="even">
#   <td class="two td_left" data-th="Last Name">
#    CHILTON-GATTEN
#   </td>
#   <td class="two td_left" data-th="First Name">
#    CANDACE
#   </td>
#   <td class="two td_left" data-th="Middle Name">
#    ALMIRA
#   </td>
#   <td class="two td_left" data-th="Sex">
#    F
#   </td>
#   <td class="two td_left" data-th="Race">
#    W
#   </td>
#   <td class="two td_right" data-th="Age">
#    35
#   </td>
#   <td class="two td_left" data-th="City">
#    FULTON
#   </td>
#   <td class="two td_left" data-th="State">
#    MO
#   </td>
#   <td class="two td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=80881&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="odd">
#   <td class="one td_left" data-th="Last Name">
#    CHRISTMAS
#   </td>
#   <td class="one td_left" data-th="First Name">
#    JUSTIN
#   </td>
#   <td class="one td_left" data-th="Middle Name">
#    LYNN
#   </td>
#   <td class="one td_left" data-th="Sex">
#    M
#   </td>
#   <td class="one td_left" data-th="Race">
#    W
#   </td>
#   <td class="one td_right" data-th="Age">
#    41
#   </td>
#   <td class="one td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="one td_left" data-th="State">
#    MO
#   </td>
#   <td class="one td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=24788&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="even">
#   <td class="two td_left" data-th="Last Name">
#    CLARK
#   </td>
#   <td class="two td_left" data-th="First Name">
#    THOMAS
#   </td>
#   <td class="two td_left" data-th="Middle Name">
#    EARL
#   </td>
#   <td class="two td_left" data-th="Sex">
#    M
#   </td>
#   <td class="two td_left" data-th="Race">
#    B
#   </td>
#   <td class="two td_right" data-th="Age">
#    64
#   </td>
#   <td class="two td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="two td_left" data-th="State">
#    MO
#   </td>
#   <td class="two td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=78312&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="odd">
#   <td class="one td_left" data-th="Last Name">
#    COCO
#   </td>
#   <td class="one td_left" data-th="First Name">
#    DREW
#   </td>
#   <td class="one td_left" data-th="Middle Name">
#    PATRICK
#   </td>
#   <td class="one td_left" data-th="Sex">
#    M
#   </td>
#   <td class="one td_left" data-th="Race">
#    W
#   </td>
#   <td class="one td_right" data-th="Age">
#    37
#   </td>
#   <td class="one td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="one td_left" data-th="State">
#    MO
#   </td>
#   <td class="one td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=35949&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="even">
#   <td class="two td_left" data-th="Last Name">
#    COLLINS
#   </td>
#   <td class="two td_left" data-th="First Name">
#    MICHAEL
#   </td>
#   <td class="two td_left" data-th="Middle Name">
#    JAMES
#   </td>
#   <td class="two td_left" data-th="Sex">
#    M
#   </td>
#   <td class="two td_left" data-th="Race">
#    W
#   </td>
#   <td class="two td_right" data-th="Age">
#    21
#   </td>
#   <td class="two td_left" data-th="City">
#    FULTON
#   </td>
#   <td class="two td_left" data-th="State">
#    MO
#   </td>
#   <td class="two td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=76466&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="odd">
#   <td class="one td_left" data-th="Last Name">
#    COMMANDER
#   </td>
#   <td class="one td_left" data-th="First Name">
#    JAVANTE
#   </td>
#   <td class="one td_left" data-th="Middle Name">
#    BRUCE
#   </td>
#   <td class="one td_left" data-th="Sex">
#    M
#   </td>
#   <td class="one td_left" data-th="Race">
#    B
#   </td>
#   <td class="one td_right" data-th="Age">
#    23
#   </td>
#   <td class="one td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="one td_left" data-th="State">
#    MO
#   </td>
#   <td class="one td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=68940&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="even">
#   <td class="two td_left" data-th="Last Name">
#    COX
#   </td>
#   <td class="two td_left" data-th="First Name">
#    JAQUE
#   </td>
#   <td class="two td_left" data-th="Middle Name">
#    DERON
#   </td>
#   <td class="two td_left" data-th="Sex">
#    M
#   </td>
#   <td class="two td_left" data-th="Race">
#    B
#   </td>
#   <td class="two td_right" data-th="Age">
#    28
#   </td>
#   <td class="two td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="two td_left" data-th="State">
#    MO
#   </td>
#   <td class="two td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=68391&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="odd">
#   <td class="one td_left" data-th="Last Name">
#    CRAIN
#   </td>
#   <td class="one td_left" data-th="First Name">
#    THOMAS
#   </td>
#   <td class="one td_left" data-th="Middle Name">
#    RAY
#   </td>
#   <td class="one td_left" data-th="Sex">
#    M
#   </td>
#   <td class="one td_left" data-th="Race">
#    W
#   </td>
#   <td class="one td_right" data-th="Age">
#    48
#   </td>
#   <td class="one td_left" data-th="City">
#    BRIGHTON
#   </td>
#   <td class="one td_left" data-th="State">
#    TN
#   </td>
#   <td class="one td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=80735&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="even">
#   <td class="two td_left" data-th="Last Name">
#    CRAWLEY
#   </td>
#   <td class="two td_left" data-th="First Name">
#    EDDIE
#   </td>
#   <td class="two td_left" data-th="Middle Name">
#    HUGHES
#   </td>
#   <td class="two td_left" data-th="Sex">
#    M
#   </td>
#   <td class="two td_left" data-th="Race">
#    B
#   </td>
#   <td class="two td_right" data-th="Age">
#    64
#   </td>
#   <td class="two td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="two td_left" data-th="State">
#    MO
#   </td>
#   <td class="two td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=10979&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!--   -->
#  <tr class="tr-paging">
#   <th class="th_left paging_row bottomPaging" colspan="93">
#    Detainee Count: 241
#    <div class="pagination pagination-right fixed-pagination" style="margin-left: 2em;">
#     <ul>
#      <li>
#       <a class="page-button" data-pagetype="btn_top" href="javascript:void(0)">
#        <i class="fa fa-angle-double-left fa-large">
#        </i>
#       </a>
#      </li>
#      <li>
#       <a class="page-button" data-pagetype="btn_prev" href="javascript:void(0)">
#        <i class="fa fa-angle-left fa-large">
#        </i>
#       </a>
#      </li>
#      <li class="disabled">
#       <a href="#">
#        Page 1 of 5
#       </a>
#      </li>
#      <li>
#       <a class="page-button" data-pagetype="btn_next" href="javascript:void(0)">
#        <i class="fa fa-angle-right fa-large">
#        </i>
#       </a>
#      </li>
#      <li>
#       <a class="page-button" data-pagetype="btn_btmm" href="javascript:void(0)">
#        <i class="fa fa-angle-double-right fa-large">
#        </i>
#       </a>
#      </li>
#     </ul>
#    </div>
#   </th>
#  </tr>
# </tbody>

# %%
for row in table.findAll('tr'):
    print(row.prettify())
# Out:
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   AARON
#  </td>
#  <td class="one td_left" data-th="First Name">
#   KEVIN
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   PHILLIP
#  </td>
#  <td class="one td_left" data-th="Sex">
#   M
#  </td>
#  <td class="one td_left" data-th="Race">
#   B
#  </td>
#  <td class="one td_right" data-th="Age">
#   23
#  </td>
#  <td class="one td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=66343&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   ACOSTA
#  </td>
#  <td class="two td_left" data-th="First Name">
#   VINCENT
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   DAVID
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   W
#  </td>
#  <td class="two td_right" data-th="Age">
#   53
#  </td>
#  <td class="two td_left" data-th="City">
#   MEXICO
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=22950&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   ACTON
#  </td>
#  <td class="one td_left" data-th="First Name">
#   ANTHONY
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   SEAN
#  </td>
#  <td class="one td_left" data-th="Sex">
#   M
#  </td>
#  <td class="one td_left" data-th="Race">
#   B
#  </td>
#  <td class="one td_right" data-th="Age">
#   26
#  </td>
#  <td class="one td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=66619&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   ADAM
#  </td>
#  <td class="two td_left" data-th="First Name">
#   OMER
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   SIRAJ
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   B
#  </td>
#  <td class="two td_right" data-th="Age">
#   30
#  </td>
#  <td class="two td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=77695&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   ADAMS
#  </td>
#  <td class="one td_left" data-th="First Name">
#   JEREMIAH
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   SETH
#  </td>
#  <td class="one td_left" data-th="Sex">
#   M
#  </td>
#  <td class="one td_left" data-th="Race">
#   W
#  </td>
#  <td class="one td_right" data-th="Age">
#   43
#  </td>
#  <td class="one td_left" data-th="City">
#   CENTRALIA
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=23883&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   ALEXANDER
#  </td>
#  <td class="two td_left" data-th="First Name">
#   BENJAMIN
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   FRANKLIN
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   B
#  </td>
#  <td class="two td_right" data-th="Age">
#   23
#  </td>
#  <td class="two td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=74927&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   ANDERSON
#  </td>
#  <td class="one td_left" data-th="First Name">
#   RICHARD
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   KENNETH
#  </td>
#  <td class="one td_left" data-th="Sex">
#   M
#  </td>
#  <td class="one td_left" data-th="Race">
#   B
#  </td>
#  <td class="one td_right" data-th="Age">
#   24
#  </td>
#  <td class="one td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=66544&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   ARCHAMBAULT
#  </td>
#  <td class="two td_left" data-th="First Name">
#   MARK
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   VINCENT
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   W
#  </td>
#  <td class="two td_right" data-th="Age">
#   56
#  </td>
#  <td class="two td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=76691&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   ARCHULETA
#  </td>
#  <td class="one td_left" data-th="First Name">
#   JUSTIN
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   LEE
#  </td>
#  <td class="one td_left" data-th="Sex">
#   M
#  </td>
#  <td class="one td_left" data-th="Race">
#   W
#  </td>
#  <td class="one td_right" data-th="Age">
#   37
#  </td>
#  <td class="one td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=23834&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   ARMSTRONG
#  </td>
#  <td class="two td_left" data-th="First Name">
#   EDWARD
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   MAHON
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   B
#  </td>
#  <td class="two td_right" data-th="Age">
#   37
#  </td>
#  <td class="two td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=63563&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   ATTERBERRY
#  </td>
#  <td class="one td_left" data-th="First Name">
#   JUSTIN
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   MICHAEL
#  </td>
#  <td class="one td_left" data-th="Sex">
#   M
#  </td>
#  <td class="one td_left" data-th="Race">
#   W
#  </td>
#  <td class="one td_right" data-th="Age">
#   27
#  </td>
#  <td class="one td_left" data-th="City">
#   HOLT SUMMIT
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=77291&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   BAKER
#  </td>
#  <td class="two td_left" data-th="First Name">
#   CHRISTOPHER
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   ALAN
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   W
#  </td>
#  <td class="two td_right" data-th="Age">
#   28
#  </td>
#  <td class="two td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=59254&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   BALDWIN
#  </td>
#  <td class="one td_left" data-th="First Name">
#   SAM
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#  </td>
#  <td class="one td_left" data-th="Sex">
#   M
#  </td>
#  <td class="one td_left" data-th="Race">
#   B
#  </td>
#  <td class="one td_right" data-th="Age">
#   26
#  </td>
#  <td class="one td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=57471&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   BARBERO
#  </td>
#  <td class="two td_left" data-th="First Name">
#   CASEY
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   TYLER
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   W
#  </td>
#  <td class="two td_right" data-th="Age">
#   28
#  </td>
#  <td class="two td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=50635&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   BARNES
#  </td>
#  <td class="one td_left" data-th="First Name">
#   DARIN
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   WAYNE
#  </td>
#  <td class="one td_left" data-th="Sex">
#   M
#  </td>
#  <td class="one td_left" data-th="Race">
#   W
#  </td>
#  <td class="one td_right" data-th="Age">
#   33
#  </td>
#  <td class="one td_left" data-th="City">
#   MOBERLY
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=77513&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   BARNHART
#  </td>
#  <td class="two td_left" data-th="First Name">
#   CHRIS
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   MICHAEL
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   W
#  </td>
#  <td class="two td_right" data-th="Age">
#   28
#  </td>
#  <td class="two td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=56348&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   BEARS
#  </td>
#  <td class="one td_left" data-th="First Name">
#   JARED
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   ANTHONY
#  </td>
#  <td class="one td_left" data-th="Sex">
#   M
#  </td>
#  <td class="one td_left" data-th="Race">
#   W
#  </td>
#  <td class="one td_right" data-th="Age">
#   19
#  </td>
#  <td class="one td_left" data-th="City">
#   BUCKNER
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=80333&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   BEL
#  </td>
#  <td class="two td_left" data-th="First Name">
#   ROBERT
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   ANTHONY
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   W
#  </td>
#  <td class="two td_right" data-th="Age">
#   34
#  </td>
#  <td class="two td_left" data-th="City">
#   BATON ROUGE
#  </td>
#  <td class="two td_left" data-th="State">
#   LA
#  </td>
#  <td class="two td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=75600&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   BENEDETTI
#  </td>
#  <td class="one td_left" data-th="First Name">
#   FRANK
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   DOMINICK
#  </td>
#  <td class="one td_left" data-th="Sex">
#   M
#  </td>
#  <td class="one td_left" data-th="Race">
#   W
#  </td>
#  <td class="one td_right" data-th="Age">
#   29
#  </td>
#  <td class="one td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=79913&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   BERARDI
#  </td>
#  <td class="two td_left" data-th="First Name">
#   DEBORAH
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   EVA
#  </td>
#  <td class="two td_left" data-th="Sex">
#   F
#  </td>
#  <td class="two td_left" data-th="Race">
#   W
#  </td>
#  <td class="two td_right" data-th="Age">
#   56
#  </td>
#  <td class="two td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=78005&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   BETTS
#  </td>
#  <td class="one td_left" data-th="First Name">
#   LAWRENCE
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   SHERRON
#  </td>
#  <td class="one td_left" data-th="Sex">
#   M
#  </td>
#  <td class="one td_left" data-th="Race">
#   B
#  </td>
#  <td class="one td_right" data-th="Age">
#   43
#  </td>
#  <td class="one td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=43249&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   BLACK
#  </td>
#  <td class="two td_left" data-th="First Name">
#   JAMIE
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   LEE
#  </td>
#  <td class="two td_left" data-th="Sex">
#   F
#  </td>
#  <td class="two td_left" data-th="Race">
#   W
#  </td>
#  <td class="two td_right" data-th="Age">
#   38
#  </td>
#  <td class="two td_left" data-th="City">
#   LOS ANGELES
#  </td>
#  <td class="two td_left" data-th="State">
#   CA
#  </td>
#  <td class="two td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=80505&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   BLAND
#  </td>
#  <td class="one td_left" data-th="First Name">
#   RANDY
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   LAMONT
#  </td>
#  <td class="one td_left" data-th="Sex">
#   M
#  </td>
#  <td class="one td_left" data-th="Race">
#   B
#  </td>
#  <td class="one td_right" data-th="Age">
#   23
#  </td>
#  <td class="one td_left" data-th="City">
#   SPRINGFIELD
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=65798&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   BOSS
#  </td>
#  <td class="two td_left" data-th="First Name">
#   JAFARI
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   RASHIDI
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   B
#  </td>
#  <td class="two td_right" data-th="Age">
#   34
#  </td>
#  <td class="two td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=60725&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   BRADLEY
#  </td>
#  <td class="one td_left" data-th="First Name">
#   JAMIE
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   MICHELLE
#  </td>
#  <td class="one td_left" data-th="Sex">
#   F
#  </td>
#  <td class="one td_left" data-th="Race">
#   W
#  </td>
#  <td class="one td_right" data-th="Age">
#   33
#  </td>
#  <td class="one td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=44762&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   BRANCH
#  </td>
#  <td class="two td_left" data-th="First Name">
#   JASON
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   STEVEN
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   W
#  </td>
#  <td class="two td_right" data-th="Age">
#   41
#  </td>
#  <td class="two td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=57402&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   BRILL
#  </td>
#  <td class="one td_left" data-th="First Name">
#   BRANDON
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   NICHOLAS
#  </td>
#  <td class="one td_left" data-th="Sex">
#   M
#  </td>
#  <td class="one td_left" data-th="Race">
#   W
#  </td>
#  <td class="one td_right" data-th="Age">
#   26
#  </td>
#  <td class="one td_left" data-th="City">
#   CLARK
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=60089&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   BROOKINS
#  </td>
#  <td class="two td_left" data-th="First Name">
#   GARY
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   LAREN
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   B
#  </td>
#  <td class="two td_right" data-th="Age">
#   60
#  </td>
#  <td class="two td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=9940&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   BROWN
#  </td>
#  <td class="one td_left" data-th="First Name">
#   BARRY
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   RONELL
#  </td>
#  <td class="one td_left" data-th="Sex">
#   M
#  </td>
#  <td class="one td_left" data-th="Race">
#   B
#  </td>
#  <td class="one td_right" data-th="Age">
#   31
#  </td>
#  <td class="one td_left" data-th="City">
#   FLORISSANT
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=80297&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   BROWN
#  </td>
#  <td class="two td_left" data-th="First Name">
#   JEREMIAH
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   EZEKIEL
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   B
#  </td>
#  <td class="two td_right" data-th="Age">
#   33
#  </td>
#  <td class="two td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=37899&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   BRYANT
#  </td>
#  <td class="one td_left" data-th="First Name">
#   JASON
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   KENNETH-LEE
#  </td>
#  <td class="one td_left" data-th="Sex">
#   M
#  </td>
#  <td class="one td_left" data-th="Race">
#   B
#  </td>
#  <td class="one td_right" data-th="Age">
#   17
#  </td>
#  <td class="one td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=80581&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   BUNTYN
#  </td>
#  <td class="two td_left" data-th="First Name">
#   JOSHUA
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   LACOY
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   B
#  </td>
#  <td class="two td_right" data-th="Age">
#   25
#  </td>
#  <td class="two td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=79524&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   BURRIS
#  </td>
#  <td class="one td_left" data-th="First Name">
#   GEOFFREY
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   DARL
#  </td>
#  <td class="one td_left" data-th="Sex">
#   M
#  </td>
#  <td class="one td_left" data-th="Race">
#   W
#  </td>
#  <td class="one td_right" data-th="Age">
#   28
#  </td>
#  <td class="one td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=55499&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   BURTON
#  </td>
#  <td class="two td_left" data-th="First Name">
#   HEIDI
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   SUE
#  </td>
#  <td class="two td_left" data-th="Sex">
#   F
#  </td>
#  <td class="two td_left" data-th="Race">
#   W
#  </td>
#  <td class="two td_right" data-th="Age">
#   39
#  </td>
#  <td class="two td_left" data-th="City">
#   HALLSVILLE
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=46477&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   BUSH
#  </td>
#  <td class="one td_left" data-th="First Name">
#   DEVON
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   ALBERT
#  </td>
#  <td class="one td_left" data-th="Sex">
#   M
#  </td>
#  <td class="one td_left" data-th="Race">
#   B
#  </td>
#  <td class="one td_right" data-th="Age">
#   22
#  </td>
#  <td class="one td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=80868&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   BUTLER
#  </td>
#  <td class="two td_left" data-th="First Name">
#   JEMELL
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   DUPRUE
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   B
#  </td>
#  <td class="two td_right" data-th="Age">
#   22
#  </td>
#  <td class="two td_left" data-th="City">
#   JEFFERSON CITY
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=72107&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   BYERS
#  </td>
#  <td class="one td_left" data-th="First Name">
#   NORISHA
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   NICOLE
#  </td>
#  <td class="one td_left" data-th="Sex">
#   F
#  </td>
#  <td class="one td_left" data-th="Race">
#   B
#  </td>
#  <td class="one td_right" data-th="Age">
#   24
#  </td>
#  <td class="one td_left" data-th="City">
#   FULTON
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=80682&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   CANFIELD
#  </td>
#  <td class="two td_left" data-th="First Name">
#   NATHAN
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   EDWARD
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   W
#  </td>
#  <td class="two td_right" data-th="Age">
#   36
#  </td>
#  <td class="two td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=79636&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   CARPENTER
#  </td>
#  <td class="one td_left" data-th="First Name">
#   KALINDA
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   MARIE
#  </td>
#  <td class="one td_left" data-th="Sex">
#   F
#  </td>
#  <td class="one td_left" data-th="Race">
#   B
#  </td>
#  <td class="one td_right" data-th="Age">
#   33
#  </td>
#  <td class="one td_left" data-th="City">
#   CENTRALIA
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=69298&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   CARTER
#  </td>
#  <td class="two td_left" data-th="First Name">
#   DARIAN
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   MAURICE
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   B
#  </td>
#  <td class="two td_right" data-th="Age">
#   25
#  </td>
#  <td class="two td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=56088&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   CAUDLE
#  </td>
#  <td class="one td_left" data-th="First Name">
#   CHRISTINE
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   ELIZABETH
#  </td>
#  <td class="one td_left" data-th="Sex">
#   F
#  </td>
#  <td class="one td_left" data-th="Race">
#   W
#  </td>
#  <td class="one td_right" data-th="Age">
#   32
#  </td>
#  <td class="one td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=41652&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   CHILTON-GATTEN
#  </td>
#  <td class="two td_left" data-th="First Name">
#   CANDACE
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   ALMIRA
#  </td>
#  <td class="two td_left" data-th="Sex">
#   F
#  </td>
#  <td class="two td_left" data-th="Race">
#   W
#  </td>
#  <td class="two td_right" data-th="Age">
#   35
#  </td>
#  <td class="two td_left" data-th="City">
#   FULTON
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=80881&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   CHRISTMAS
#  </td>
#  <td class="one td_left" data-th="First Name">
#   JUSTIN
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   LYNN
#  </td>
#  <td class="one td_left" data-th="Sex">
#   M
#  </td>
#  <td class="one td_left" data-th="Race">
#   W
#  </td>
#  <td class="one td_right" data-th="Age">
#   41
#  </td>
#  <td class="one td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=24788&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   CLARK
#  </td>
#  <td class="two td_left" data-th="First Name">
#   THOMAS
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   EARL
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   B
#  </td>
#  <td class="two td_right" data-th="Age">
#   64
#  </td>
#  <td class="two td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=78312&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   COCO
#  </td>
#  <td class="one td_left" data-th="First Name">
#   DREW
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   PATRICK
#  </td>
#  <td class="one td_left" data-th="Sex">
#   M
#  </td>
#  <td class="one td_left" data-th="Race">
#   W
#  </td>
#  <td class="one td_right" data-th="Age">
#   37
#  </td>
#  <td class="one td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=35949&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   COLLINS
#  </td>
#  <td class="two td_left" data-th="First Name">
#   MICHAEL
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   JAMES
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   W
#  </td>
#  <td class="two td_right" data-th="Age">
#   21
#  </td>
#  <td class="two td_left" data-th="City">
#   FULTON
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=76466&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   COMMANDER
#  </td>
#  <td class="one td_left" data-th="First Name">
#   JAVANTE
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   BRUCE
#  </td>
#  <td class="one td_left" data-th="Sex">
#   M
#  </td>
#  <td class="one td_left" data-th="Race">
#   B
#  </td>
#  <td class="one td_right" data-th="Age">
#   23
#  </td>
#  <td class="one td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=68940&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   COX
#  </td>
#  <td class="two td_left" data-th="First Name">
#   JAQUE
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   DERON
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   B
#  </td>
#  <td class="two td_right" data-th="Age">
#   28
#  </td>
#  <td class="two td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=68391&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   CRAIN
#  </td>
#  <td class="one td_left" data-th="First Name">
#   THOMAS
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   RAY
#  </td>
#  <td class="one td_left" data-th="Sex">
#   M
#  </td>
#  <td class="one td_left" data-th="Race">
#   W
#  </td>
#  <td class="one td_right" data-th="Age">
#   48
#  </td>
#  <td class="one td_left" data-th="City">
#   BRIGHTON
#  </td>
#  <td class="one td_left" data-th="State">
#   TN
#  </td>
#  <td class="one td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=80735&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   CRAWLEY
#  </td>
#  <td class="two td_left" data-th="First Name">
#   EDDIE
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   HUGHES
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   B
#  </td>
#  <td class="two td_right" data-th="Age">
#   64
#  </td>
#  <td class="two td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=10979&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="tr-paging">
#  <th class="th_left paging_row bottomPaging" colspan="93">
#   Detainee Count: 241
#   <div class="pagination pagination-right fixed-pagination" style="margin-left: 2em;">
#    <ul>
#     <li>
#      <a class="page-button" data-pagetype="btn_top" href="javascript:void(0)">
#       <i class="fa fa-angle-double-left fa-large">
#       </i>
#      </a>
#     </li>
#     <li>
#      <a class="page-button" data-pagetype="btn_prev" href="javascript:void(0)">
#       <i class="fa fa-angle-left fa-large">
#       </i>
#      </a>
#     </li>
#     <li class="disabled">
#      <a href="#">
#       Page 1 of 5
#      </a>
#     </li>
#     <li>
#      <a class="page-button" data-pagetype="btn_next" href="javascript:void(0)">
#       <i class="fa fa-angle-right fa-large">
#       </i>
#      </a>
#     </li>
#     <li>
#      <a class="page-button" data-pagetype="btn_btmm" href="javascript:void(0)">
#       <i class="fa fa-angle-double-right fa-large">
#       </i>
#      </a>
#     </li>
#    </ul>
#   </div>
#  </th>
# </tr>

# %%
for row in table.findAll('tr'):
    for cell in row.findAll('td'):
        print(cell.text)
# Out:
# AARON
# KEVIN
# PHILLIP
# M
# B
# 23
# COLUMBIA
# MO
#
#  Details
#
# ACOSTA
# VINCENT
# DAVID
# M
# W
# 53
# MEXICO
# MO
#
#  Details
#
# ACTON
# ANTHONY
# SEAN
# M
# B
# 26
# COLUMBIA
# MO
#
#  Details
#
# ADAM
# OMER
# SIRAJ
# M
# B
# 30
# COLUMBIA
# MO
#
#  Details
#
# ADAMS
# JEREMIAH
# SETH
# M
# W
# 43
# CENTRALIA
# MO
#
#  Details
#
# ALEXANDER
# BENJAMIN
# FRANKLIN
# M
# B
# 23
# COLUMBIA
# MO
#
#  Details
#
# ANDERSON
# RICHARD
# KENNETH
# M
# B
# 24
# COLUMBIA
# MO
#
#  Details
#
# ARCHAMBAULT
# MARK
# VINCENT
# M
# W
# 56
# COLUMBIA
# MO
#
#  Details
#
# ARCHULETA
# JUSTIN
# LEE
# M
# W
# 37
# COLUMBIA
# MO
#
#  Details
#
# ARMSTRONG
# EDWARD
# MAHON
# M
# B
# 37
# COLUMBIA
# MO
#
#  Details
#
# ATTERBERRY
# JUSTIN
# MICHAEL
# M
# W
# 27
# HOLT SUMMIT
# MO
#
#  Details
#
# BAKER
# CHRISTOPHER
# ALAN
# M
# W
# 28
# COLUMBIA
# MO
#
#  Details
#
# BALDWIN
# SAM
#
# M
# B
# 26
# COLUMBIA
# MO
#
#  Details
#
# BARBERO
# CASEY
# TYLER
# M
# W
# 28
# COLUMBIA
# MO
#
#  Details
#
# BARNES
# DARIN
# WAYNE
# M
# W
# 33
# MOBERLY
# MO
#
#  Details
#
# BARNHART
# CHRIS
# MICHAEL
# M
# W
# 28
# COLUMBIA
# MO
#
#  Details
#
# BEARS
# JARED
# ANTHONY
# M
# W
# 19
# BUCKNER
# MO
#
#  Details
#
# BEL
# ROBERT
# ANTHONY
# M
# W
# 34
# BATON ROUGE
# LA
#
#  Details
#
# BENEDETTI
# FRANK
# DOMINICK
# M
# W
# 29
# COLUMBIA
# MO
#
#  Details
#
# BERARDI
# DEBORAH
# EVA
# F
# W
# 56
# COLUMBIA
# MO
#
#  Details
#
# BETTS
# LAWRENCE
# SHERRON
# M
# B
# 43
# COLUMBIA
# MO
#
#  Details
#
# BLACK
# JAMIE
# LEE
# F
# W
# 38
# LOS ANGELES
# CA
#
#  Details
#
# BLAND
# RANDY
# LAMONT
# M
# B
# 23
# SPRINGFIELD
# MO
#
#  Details
#
# BOSS
# JAFARI
# RASHIDI
# M
# B
# 34
# COLUMBIA
# MO
#
#  Details
#
# BRADLEY
# JAMIE
# MICHELLE
# F
# W
# 33
# COLUMBIA
# MO
#
#  Details
#
# BRANCH
# JASON
# STEVEN
# M
# W
# 41
# COLUMBIA
# MO
#
#  Details
#
# BRILL
# BRANDON
# NICHOLAS
# M
# W
# 26
# CLARK
# MO
#
#  Details
#
# BROOKINS
# GARY
# LAREN
# M
# B
# 60
# COLUMBIA
# MO
#
#  Details
#
# BROWN
# BARRY
# RONELL
# M
# B
# 31
# FLORISSANT
# MO
#
#  Details
#
# BROWN
# JEREMIAH
# EZEKIEL
# M
# B
# 33
# COLUMBIA
# MO
#
#  Details
#
# BRYANT
# JASON
# KENNETH-LEE
# M
# B
# 17
# COLUMBIA
# MO
#
#  Details
#
# BUNTYN
# JOSHUA
# LACOY
# M
# B
# 25
# COLUMBIA
# MO
#
#  Details
#
# BURRIS
# GEOFFREY
# DARL
# M
# W
# 28
# COLUMBIA
# MO
#
#  Details
#
# BURTON
# HEIDI
# SUE
# F
# W
# 39
# HALLSVILLE
# MO
#
#  Details
#
# BUSH
# DEVON
# ALBERT
# M
# B
# 22
# COLUMBIA
# MO
#
#  Details
#
# BUTLER
# JEMELL
# DUPRUE
# M
# B
# 22
# JEFFERSON CITY
# MO
#
#  Details
#
# BYERS
# NORISHA
# NICOLE
# F
# B
# 24
# FULTON
# MO
#
#  Details
#
# CANFIELD
# NATHAN
# EDWARD
# M
# W
# 36
# COLUMBIA
# MO
#
#  Details
#
# CARPENTER
# KALINDA
# MARIE
# F
# B
# 33
# CENTRALIA
# MO
#
#  Details
#
# CARTER
# DARIAN
# MAURICE
# M
# B
# 25
# COLUMBIA
# MO
#
#  Details
#
# CAUDLE
# CHRISTINE
# ELIZABETH
# F
# W
# 32
# COLUMBIA
# MO
#
#  Details
#
# CHILTON-GATTEN
# CANDACE
# ALMIRA
# F
# W
# 35
# FULTON
# MO
#
#  Details
#
# CHRISTMAS
# JUSTIN
# LYNN
# M
# W
# 41
# COLUMBIA
# MO
#
#  Details
#
# CLARK
# THOMAS
# EARL
# M
# B
# 64
# COLUMBIA
# MO
#
#  Details
#
# COCO
# DREW
# PATRICK
# M
# W
# 37
# COLUMBIA
# MO
#
#  Details
#
# COLLINS
# MICHAEL
# JAMES
# M
# W
# 21
# FULTON
# MO
#
#  Details
#
# COMMANDER
# JAVANTE
# BRUCE
# M
# B
# 23
# COLUMBIA
# MO
#
#  Details
#
# COX
# JAQUE
# DERON
# M
# B
# 28
# COLUMBIA
# MO
#
#  Details
#
# CRAIN
# THOMAS
# RAY
# M
# W
# 48
# BRIGHTON
# TN
#
#  Details
#
# CRAWLEY
# EDDIE
# HUGHES
# M
# B
# 64
# COLUMBIA
# MO
#
#  Details
